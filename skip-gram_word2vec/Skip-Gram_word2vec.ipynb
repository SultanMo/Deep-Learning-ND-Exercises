# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:13, 2.38MB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5 # from Mikolov et al. NIPS paper
word_count = Counter(int_words)
total_count = len(int_words)
freq = {word: count/total_count for word, count in word_count.items()}
prob = {word: 1 - np.sqrt(threshold/freq[word]) for word in freq}
train_words = [word for word in int_words if prob[word] < random.random()]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''

    random_n = random.randint(1, window_size+1)
    start_idx = idx - random_n if (idx - random_n) > 0 else 0
    end_idx = idx + random_n
    target_words = set(words[start_idx:idx]+ words[idx+1:end_idx+1])
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None])
    labels = tf.placeholder(tf.int32, [None,None])

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 300 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1)) # embedding weight matrix
    embed = tf.nn.embedding_lookup(embedding, inputs) # tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))#  softmax weight matrix
    softmax_b = tf.Variable(tf.zeros(n_vocab))# softmax biases
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 15
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/15 Iteration: 100 Avg. Training loss: 5.7540 0.0411 sec/batch
# Epoch 1/15 Iteration: 200 Avg. Training loss: 5.7327 0.0377 sec/batch
# Epoch 1/15 Iteration: 300 Avg. Training loss: 5.5789 0.0378 sec/batch
# Epoch 1/15 Iteration: 400 Avg. Training loss: 5.7162 0.0376 sec/batch
# Epoch 1/15 Iteration: 500 Avg. Training loss: 5.6282 0.0378 sec/batch
# Epoch 1/15 Iteration: 600 Avg. Training loss: 5.6272 0.0376 sec/batch
# Epoch 1/15 Iteration: 700 Avg. Training loss: 5.6814 0.0376 sec/batch
# Epoch 1/15 Iteration: 800 Avg. Training loss: 5.6269 0.0376 sec/batch
# Epoch 1/15 Iteration: 900 Avg. Training loss: 5.5475 0.0376 sec/batch
# Epoch 1/15 Iteration: 1000 Avg. Training loss: 5.5483 0.0377 sec/batch
# Nearest to who: dominator, gaited, milky, alexandrians, fida, piron, skookum, ncsa,
# Nearest to history: fails, panoramas, inquest, refutations, rhymes, psychometric, enormous, guelfs,
# Nearest to has: thor, hollandic, lands, hating, suet, duddy, incompleteness, chalumeau,
# Nearest to so: europeans, rhythmically, pontus, gaited, citigroup, search, philologist, frizer,
# Nearest to a: peacefully, known, amuck, nomological, charcoal, nightingale, transmitted, i,
# Nearest to two: hao, nasty, tolbert, acres, adaptions, ner, hulagu, hyde,
# Nearest to about: biro, telophase, releases, wogan, wichita, odowska, observations, hypothesised,
# Nearest to also: starches, animator, aromatics, feeder, leaning, primary, accused, multiples,
# Nearest to active: warangal, smugglers, mischief, argue, bani, ampere, neh, minter,
# Nearest to channel: nutrition, likenesses, possesses, cooling, segundo, shred, stony, cortlandt,
# Nearest to orthodox: bellevue, envelope, rta, isaacs, oyly, tambalacoque, iom, possessors,
# Nearest to mean: multicultural, mbeki, slain, analysts, everquest, acetylsalicylic, forgiveness, tinged,
# Nearest to stage: quaternion, secant, petri, shingles, free, gardens, chow, counsel,
# Nearest to pope: franck, reader, kara, bremsstrahlung, pleated, indoctrination, humus, csm,
# Nearest to discovered: mattel, glamorgan, overran, invincible, subscription, acknowledging, astray, domestically,
# Nearest to ocean: cartridge, mornay, dominate, negus, nta, id, wtoo, atahualpa,
# Epoch 1/15 Iteration: 1100 Avg. Training loss: 5.5745 0.0389 sec/batch
# Epoch 1/15 Iteration: 1200 Avg. Training loss: 5.4729 0.0377 sec/batch
# Epoch 1/15 Iteration: 1300 Avg. Training loss: 5.4173 0.0377 sec/batch
# Epoch 1/15 Iteration: 1400 Avg. Training loss: 5.3170 0.0375 sec/batch
# Epoch 1/15 Iteration: 1500 Avg. Training loss: 5.2292 0.0378 sec/batch
# Epoch 1/15 Iteration: 1600 Avg. Training loss: 5.2357 0.0378 sec/batch
# Epoch 1/15 Iteration: 1700 Avg. Training loss: 5.1474 0.0378 sec/batch
# Epoch 1/15 Iteration: 1800 Avg. Training loss: 5.1553 0.0377 sec/batch
# Epoch 1/15 Iteration: 1900 Avg. Training loss: 5.0775 0.0377 sec/batch
# Epoch 1/15 Iteration: 2000 Avg. Training loss: 5.0303 0.0376 sec/batch
# Nearest to who: milky, dominator, gaited, visible, whip, godhead, alexandrians, organisations,
# Nearest to history: fails, panoramas, rhymes, enormous, refutations, intermolecular, inquest, pedro,
# Nearest to has: lands, thor, hollandic, believed, seconds, incompleteness, classes, suet,
# Nearest to so: europeans, search, manufactured, gaited, philologist, would, frizer, crisscrossed,
# Nearest to a: people, transmitted, peacefully, known, i, stress, college, amuck,
# Nearest to two: nasty, hao, acres, tolbert, hulagu, adaptions, invades, ner,
# Nearest to about: observations, biro, releases, wichita, praised, portrait, wogan, telophase,
# Nearest to also: primary, accused, may, alleged, leaning, starches, draw, terms,
# Nearest to active: warangal, argue, smugglers, mischief, data, ampere, rejects, resolved,
# Nearest to channel: nutrition, cooling, possesses, fans, descartes, certain, accepting, possible,
# Nearest to orthodox: envelope, bellevue, rta, displaying, isaacs, possessors, institutions, gdb,
# Nearest to mean: multicultural, slain, analysts, lieutenant, approach, johnson, mbeki, everquest,
# Nearest to stage: quaternion, secant, free, petri, shingles, nbc, gardens, bittersweet,
# Nearest to pope: reader, microchips, kara, battle, equal, bremsstrahlung, franck, violet,
# Nearest to discovered: mattel, populations, invincible, prediction, acknowledging, glamorgan, astray, subscription,
# Nearest to ocean: cartridge, dominate, cover, add, learn, mornay, nta, id,
# Epoch 1/15 Iteration: 2100 Avg. Training loss: 4.9606 0.0388 sec/batch
# Epoch 1/15 Iteration: 2200 Avg. Training loss: 4.9547 0.0376 sec/batch
# Epoch 1/15 Iteration: 2300 Avg. Training loss: 4.9325 0.0377 sec/batch
# Epoch 1/15 Iteration: 2400 Avg. Training loss: 4.9306 0.0377 sec/batch
# Epoch 1/15 Iteration: 2500 Avg. Training loss: 4.8837 0.0377 sec/batch
# Epoch 1/15 Iteration: 2600 Avg. Training loss: 4.8803 0.0377 sec/batch
# Epoch 1/15 Iteration: 2700 Avg. Training loss: 4.8649 0.0377 sec/batch
# Epoch 1/15 Iteration: 2800 Avg. Training loss: 4.8584 0.0377 sec/batch
# Epoch 1/15 Iteration: 2900 Avg. Training loss: 4.8610 0.0377 sec/batch
# Epoch 1/15 Iteration: 3000 Avg. Training loss: 4.8334 0.0377 sec/batch
# Nearest to who: milky, dominator, whip, gaited, would, apostolic, glaciers, fida,
# Nearest to history: fails, enormous, refutations, panoramas, mourner, intermolecular, rhymes, pedro,
# Nearest to has: thor, lands, hollandic, incompleteness, believed, seconds, interdisciplinary, eternal,
# Nearest to so: search, philologist, manufactured, eliminate, europeans, gaited, frizer, rhythmically,
# Nearest to a: peacefully, transmitted, amuck, equitable, profitable, bodily, stress, people,
# Nearest to two: nasty, hao, hulagu, adaptions, acres, invades, indebted, tolbert,
# Nearest to about: releases, wichita, biro, observations, wogan, praised, heralds, behavioral,
# Nearest to also: primary, starches, multiples, alleged, feeder, animator, leaning, sponsorship,
# Nearest to active: warangal, smugglers, argue, mischief, ampere, data, inference, governors,
# Nearest to channel: cooling, nutrition, possesses, whitman, sensation, pat, descartes, fans,
# Nearest to orthodox: envelope, bellevue, oyly, isaacs, possessors, rta, convene, displaying,
# Nearest to mean: multicultural, analysts, slain, mbeki, lieutenant, odyssey, everquest, approach,
# Nearest to stage: quaternion, secant, petri, free, shingles, counsel, chow, nbc,
# Nearest to pope: reader, microchips, kara, indoctrination, enthusiasms, franck, violet, bremsstrahlung,
# Nearest to discovered: mattel, subscription, invincible, acknowledging, overran, populations, glamorgan, domestically,
# Nearest to ocean: cartridge, cover, dominate, nta, add, mornay, palo, atahualpa,
# Epoch 1/15 Iteration: 3100 Avg. Training loss: 4.8235 0.0387 sec/batch
# Epoch 1/15 Iteration: 3200 Avg. Training loss: 4.8135 0.0376 sec/batch
# Epoch 1/15 Iteration: 3300 Avg. Training loss: 4.7634 0.0379 sec/batch
# Epoch 1/15 Iteration: 3400 Avg. Training loss: 4.7815 0.0376 sec/batch
# Epoch 1/15 Iteration: 3500 Avg. Training loss: 4.7672 0.0380 sec/batch
# Epoch 1/15 Iteration: 3600 Avg. Training loss: 4.7182 0.0379 sec/batch
# Epoch 1/15 Iteration: 3700 Avg. Training loss: 4.7583 0.0378 sec/batch
# Epoch 1/15 Iteration: 3800 Avg. Training loss: 4.8109 0.0377 sec/batch
# Epoch 1/15 Iteration: 3900 Avg. Training loss: 4.7325 0.0376 sec/batch
# Epoch 1/15 Iteration: 4000 Avg. Training loss: 4.6887 0.0377 sec/batch
# Nearest to who: dominator, milky, whip, apostolic, gaited, would, fida, glaciers,
# Nearest to history: fails, refutations, enormous, panoramas, mourner, psychometric, inheritance, recieves,
# Nearest to has: thor, lands, interdisciplinary, hollandic, suet, believed, incompleteness, seconds,
# Nearest to so: search, philologist, gaited, eliminate, manufactured, frizer, pontus, rhythmically,
# Nearest to a: peacefully, equitable, transmitted, bodily, subscriber, stress, amuck, nomological,
# Nearest to two: nasty, hao, hulagu, adaptions, acres, indebted, invades, resins,
# Nearest to about: wichita, wogan, biro, observations, releases, behavioral, praised, telophase,
# Nearest to also: primary, feeder, multiples, alleged, starches, sponsorship, leaning, animator,
# Nearest to active: warangal, smugglers, mischief, argue, ampere, kabir, data, fuerza,
# Nearest to channel: cooling, nutrition, possesses, whitman, stony, descartes, stabbing, pci,
# Nearest to orthodox: bellevue, envelope, oyly, isaacs, possessors, convene, tambalacoque, statuette,
# Nearest to mean: analysts, multicultural, mbeki, samantha, slain, approach, polyhedron, everquest,
# Nearest to stage: quaternion, petri, secant, free, shingles, chow, counsel, bittersweet,
# Nearest to pope: enthusiasms, microchips, indoctrination, franck, reader, kara, battle, his,
# Nearest to discovered: mattel, subscription, invincible, acknowledging, overran, astray, domestically, populations,
# Nearest to ocean: cartridge, cover, nta, approx, palo, mornay, atahualpa, dominate,
# Epoch 1/15 Iteration: 4100 Avg. Training loss: 4.7255 0.0386 sec/batch
# Epoch 1/15 Iteration: 4200 Avg. Training loss: 4.6778 0.0377 sec/batch
# Epoch 1/15 Iteration: 4300 Avg. Training loss: 4.5986 0.0378 sec/batch
# Epoch 1/15 Iteration: 4400 Avg. Training loss: 4.6438 0.0377 sec/batch
# Epoch 1/15 Iteration: 4500 Avg. Training loss: 4.6632 0.0377 sec/batch
# Epoch 1/15 Iteration: 4600 Avg. Training loss: 4.6741 0.0378 sec/batch
# Epoch 2/15 Iteration: 4700 Avg. Training loss: 4.6047 0.0283 sec/batch
# Epoch 2/15 Iteration: 4800 Avg. Training loss: 4.5400 0.0378 sec/batch
# Epoch 2/15 Iteration: 4900 Avg. Training loss: 4.5184 0.0376 sec/batch
# Epoch 2/15 Iteration: 5000 Avg. Training loss: 4.5006 0.0378 sec/batch
# Nearest to who: dominator, apostolic, gaited, would, miraculous, milky, whip, fida,
# Nearest to history: fails, refutations, panoramas, enormous, mourner, psychometric, kierkegaard, masculist,
# Nearest to has: thor, lands, suet, interdisciplinary, believed, hollandic, hating, chalumeau,
# Nearest to so: rhythmically, search, frizer, manufactured, eliminate, citigroup, gaited, would,
# Nearest to a: transmitted, bodily, peacefully, subscriber, stress, amuck, equitable, nomological,
# Nearest to two: nasty, hao, acres, hulagu, nine, hyde, indebted, adaptions,
# Nearest to about: wichita, biro, observations, wogan, telophase, releases, behavioral, heralds,
# Nearest to also: primary, multiples, feeder, starches, cytology, animator, sponsorship, alleged,
# Nearest to active: warangal, smugglers, argue, ampere, kabir, mischief, supersede, supervisor,
# Nearest to channel: cooling, nutrition, possesses, flint, segundo, stony, whitman, stabbing,
# Nearest to orthodox: bellevue, envelope, oyly, statuette, isaacs, possessors, tambalacoque, beheld,
# Nearest to mean: analysts, mbeki, polyhedron, samantha, approach, akhmad, diner, multicultural,
# Nearest to stage: quaternion, petri, shingles, secant, bittersweet, free, counsel, chow,
# Nearest to pope: enthusiasms, franck, his, battle, microchips, indoctrination, reader, kara,
# Nearest to discovered: mattel, subscription, overran, invincible, astray, domestically, pelagius, glamorgan,
# Nearest to ocean: cartridge, cover, nta, mornay, approx, palo, cross, atahualpa,
# Epoch 2/15 Iteration: 5100 Avg. Training loss: 4.4924 0.0388 sec/batch
# Epoch 2/15 Iteration: 5200 Avg. Training loss: 4.4794 0.0376 sec/batch
# Epoch 2/15 Iteration: 5300 Avg. Training loss: 4.4745 0.0377 sec/batch
# Epoch 2/15 Iteration: 5400 Avg. Training loss: 4.5256 0.0377 sec/batch
# Epoch 2/15 Iteration: 5500 Avg. Training loss: 4.4532 0.0378 sec/batch
# Epoch 2/15 Iteration: 5600 Avg. Training loss: 4.4556 0.0376 sec/batch
# Epoch 2/15 Iteration: 5700 Avg. Training loss: 4.4479 0.0376 sec/batch
# Epoch 2/15 Iteration: 5800 Avg. Training loss: 4.4060 0.0377 sec/batch
# Epoch 2/15 Iteration: 5900 Avg. Training loss: 4.4202 0.0377 sec/batch
# Epoch 2/15 Iteration: 6000 Avg. Training loss: 4.4232 0.0376 sec/batch
# Nearest to who: dominator, apostolic, miraculous, gaited, fida, would, fp, whip,
# Nearest to history: fails, panoramas, psychometric, refutations, enormous, masculist, kierkegaard, mourner,
# Nearest to has: thor, interdisciplinary, lands, suet, chalumeau, hating, believed, hollandic,
# Nearest to so: rhythmically, frizer, search, eliminate, citigroup, exact, would, oddly,
# Nearest to a: transmitted, peacefully, stress, amuck, bodily, battleships, nomological, equitable,
# Nearest to two: acres, five, hao, hulagu, tanker, nasty, indebted, adaptions,
# Nearest to about: biro, wichita, observations, wogan, heralds, telophase, releases, shoved,
# Nearest to also: multiples, primary, starches, cytology, terms, feeder, neighbourhood, sponsorship,
# Nearest to active: warangal, smugglers, argue, ampere, kabir, data, sejanus, supersede,
# Nearest to channel: cooling, nutrition, segundo, whitman, possesses, flint, stony, cortlandt,
# Nearest to orthodox: oyly, bellevue, statuette, tambalacoque, beheld, institutions, possessors, envelope,
# Nearest to mean: analysts, mbeki, approach, polyhedron, samantha, diner, akhmad, dem,
# Nearest to stage: quaternion, petri, shingles, bittersweet, secant, free, counsel, nbc,
# Nearest to pope: enthusiasms, franck, his, reader, microchips, indoctrination, kara, battle,
# Nearest to discovered: mattel, subscription, invincible, pelagius, astray, overran, prediction, cohen,
# Nearest to ocean: cartridge, cover, nta, approx, mornay, palo, redstone, atahualpa,
# Epoch 2/15 Iteration: 6100 Avg. Training loss: 4.4344 0.0387 sec/batch
# Epoch 2/15 Iteration: 6200 Avg. Training loss: 4.4026 0.0375 sec/batch
# Epoch 2/15 Iteration: 6300 Avg. Training loss: 4.4437 0.0376 sec/batch
# Epoch 2/15 Iteration: 6400 Avg. Training loss: 4.3640 0.0376 sec/batch
# Epoch 2/15 Iteration: 6500 Avg. Training loss: 4.4021 0.0377 sec/batch
# Epoch 2/15 Iteration: 6600 Avg. Training loss: 4.3970 0.0378 sec/batch
# Epoch 2/15 Iteration: 6700 Avg. Training loss: 4.3815 0.0377 sec/batch
# Epoch 2/15 Iteration: 6800 Avg. Training loss: 4.3608 0.0377 sec/batch
# Epoch 2/15 Iteration: 6900 Avg. Training loss: 4.4114 0.0377 sec/batch
# Epoch 2/15 Iteration: 7000 Avg. Training loss: 4.3847 0.0376 sec/batch
# Nearest to who: dominator, apostolic, miraculous, would, whip, gaited, fida, dits,
# Nearest to history: panoramas, psychometric, fails, refutations, masculist, enormous, qam, mourner,
# Nearest to has: thor, suet, interdisciplinary, lands, incompleteness, hating, believed, chalumeau,
# Nearest to so: eliminate, rhythmically, frizer, citigroup, search, manufactured, would, rosario,
# Nearest to a: peacefully, amuck, only, bodily, nomological, offerings, enthusiasts, transmitted,
# Nearest to two: five, acres, nine, hulagu, hao, nasty, six, ner,
# Nearest to about: observations, biro, wichita, telophase, wogan, heralds, shoved, kansai,
# Nearest to also: multiples, primary, terms, starches, cytology, neighbourhood, uncovered, feeder,
# Nearest to active: warangal, smugglers, supersede, kabir, argue, sejanus, governors, mischief,
# Nearest to channel: nutrition, cooling, likenesses, dhcp, segundo, flint, cortlandt, possesses,
# Nearest to orthodox: orthodoxy, monasteries, oyly, tambalacoque, statuette, bellevue, beheld, institutions,
# Nearest to mean: analysts, approach, polyhedron, mbeki, akhmad, diner, multicultural, keyed,
# Nearest to stage: quaternion, petri, bittersweet, shingles, free, secant, nbc, screenplays,
# Nearest to pope: enthusiasms, reader, franck, indoctrination, kara, weert, microchips, deter,
# Nearest to discovered: mattel, subscription, pelagius, astray, prediction, invincible, cohen, overran,
# Nearest to ocean: tanzania, nta, cartridge, cover, palo, sewage, atahualpa, mornay,
# Epoch 2/15 Iteration: 7100 Avg. Training loss: 4.3696 0.0388 sec/batch
# Epoch 2/15 Iteration: 7200 Avg. Training loss: 4.4047 0.0377 sec/batch
# Epoch 2/15 Iteration: 7300 Avg. Training loss: 4.3605 0.0378 sec/batch
# Epoch 2/15 Iteration: 7400 Avg. Training loss: 4.3940 0.0377 sec/batch
# Epoch 2/15 Iteration: 7500 Avg. Training loss: 4.4097 0.0378 sec/batch
# Epoch 2/15 Iteration: 7600 Avg. Training loss: 4.3483 0.0378 sec/batch
# Epoch 2/15 Iteration: 7700 Avg. Training loss: 4.3711 0.0377 sec/batch
# Epoch 2/15 Iteration: 7800 Avg. Training loss: 4.3694 0.0376 sec/batch
# Epoch 2/15 Iteration: 7900 Avg. Training loss: 4.3030 0.0379 sec/batch
# Epoch 2/15 Iteration: 8000 Avg. Training loss: 4.3315 0.0375 sec/batch
# Nearest to who: apostolic, dominator, miraculous, whip, fida, would, milky, natives,
# Nearest to history: psychometric, panoramas, fails, kierkegaard, refutations, scandinavians, documents, mourner,
# Nearest to has: thor, interdisciplinary, suet, incompleteness, chalumeau, lands, juggalo, believed,
# Nearest to so: eliminate, rhythmically, citigroup, frizer, would, rosario, nepheline, manufactured,
# Nearest to a: only, enthusiasts, dah, neh, peacefully, i, amuck, equitable,
# Nearest to two: five, nine, six, eight, hulagu, hao, tanker, acres,
# Nearest to about: biro, observations, telophase, wichita, wogan, tilted, heralds, post,
# Nearest to also: multiples, terms, cytology, primary, neighbourhood, feeder, starches, aromatics,
# Nearest to active: warangal, smugglers, supersede, kabir, sejanus, argue, illawarra, mischief,
# Nearest to channel: cooling, nutrition, dhcp, flint, likenesses, pci, segundo, possesses,
# Nearest to orthodox: monasteries, orthodoxy, tambalacoque, oyly, catechism, bellevue, statuette, institutions,
# Nearest to mean: analysts, polyhedron, akhmad, keyed, approach, mbeki, recursive, dem,
# Nearest to stage: quaternion, petri, shingles, bittersweet, screenplays, free, secant, nbc,
# Nearest to pope: enthusiasms, deter, franck, kara, indoctrination, weert, reader, vita,
# Nearest to discovered: subscription, mattel, prediction, pelagius, astray, overran, opposites, cohen,
# Nearest to ocean: tanzania, harbour, cover, nta, mexico, sewage, srpska, mornay,
# Epoch 2/15 Iteration: 8100 Avg. Training loss: 4.3567 0.0389 sec/batch
# Epoch 2/15 Iteration: 8200 Avg. Training loss: 4.2794 0.0380 sec/batch
# Epoch 2/15 Iteration: 8300 Avg. Training loss: 4.4030 0.0378 sec/batch
# Epoch 2/15 Iteration: 8400 Avg. Training loss: 4.3816 0.0378 sec/batch
# Epoch 2/15 Iteration: 8500 Avg. Training loss: 4.3637 0.0377 sec/batch
# Epoch 2/15 Iteration: 8600 Avg. Training loss: 4.2639 0.0377 sec/batch
# Epoch 2/15 Iteration: 8700 Avg. Training loss: 4.2784 0.0374 sec/batch
# Epoch 2/15 Iteration: 8800 Avg. Training loss: 4.3400 0.0378 sec/batch
# Epoch 2/15 Iteration: 8900 Avg. Training loss: 4.2201 0.0377 sec/batch
# Epoch 2/15 Iteration: 9000 Avg. Training loss: 4.3096 0.0379 sec/batch
# Nearest to who: dominator, apostolic, whip, miraculous, natives, fida, milky, would,
# Nearest to history: psychometric, panoramas, scandinavians, kierkegaard, percentile, qam, documents, enormous,
# Nearest to has: thor, suet, lands, hating, juggalo, monetarist, incompleteness, interdisciplinary,
# Nearest to so: eliminate, frizer, citigroup, rhythmically, nepheline, would, rosario, gaited,
# Nearest to a: only, neh, gradius, amuck, noin, i, dah, enthusiasts,
# Nearest to two: five, nine, eight, six, zero, acres, hao, est,
# Nearest to about: biro, observations, wichita, telophase, wogan, tilted, heralds, hingis,
# Nearest to also: primary, multiples, feeder, neighbourhood, aromatics, cytology, amigos, terms,
# Nearest to active: warangal, smugglers, supersede, kabir, governors, sejanus, illawarra, afghan,
# Nearest to channel: dhcp, cooling, nutrition, likenesses, flint, segundo, pci, possesses,
# Nearest to orthodox: monasteries, tambalacoque, catechism, orthodoxy, oyly, judaism, bellevue, possessors,
# Nearest to mean: polyhedron, approach, analysts, akhmad, recursive, keyed, senussi, mbeki,
# Nearest to stage: petri, quaternion, bittersweet, shingles, screenplays, nbc, free, chow,
# Nearest to pope: enthusiasms, deter, franck, vita, kara, weert, reader, tie,
# Nearest to discovered: pelagius, mattel, opposites, invincible, subscription, astray, overran, nanaimo,
# Nearest to ocean: tanzania, harbour, nta, sewage, cover, mexico, palo, srpska,
# Epoch 2/15 Iteration: 9100 Avg. Training loss: 4.2847 0.0388 sec/batch
# Epoch 2/15 Iteration: 9200 Avg. Training loss: 4.2974 0.0378 sec/batch
# Epoch 3/15 Iteration: 9300 Avg. Training loss: 4.3183 0.0180 sec/batch
# Epoch 3/15 Iteration: 9400 Avg. Training loss: 4.2291 0.0378 sec/batch
# Epoch 3/15 Iteration: 9500 Avg. Training loss: 4.1913 0.0378 sec/batch
# Epoch 3/15 Iteration: 9600 Avg. Training loss: 4.1633 0.0380 sec/batch
# Epoch 3/15 Iteration: 9700 Avg. Training loss: 4.2134 0.0376 sec/batch
# Epoch 3/15 Iteration: 9800 Avg. Training loss: 4.1970 0.0379 sec/batch
# Epoch 3/15 Iteration: 9900 Avg. Training loss: 4.2024 0.0378 sec/batch
# Epoch 3/15 Iteration: 10000 Avg. Training loss: 4.1311 0.0378 sec/batch
# Nearest to who: dominator, apostolic, whip, natives, fida, faction, milky, miraculous,
# Nearest to history: psychometric, panoramas, qam, percentile, documents, scandinavians, dun, paragraphs,
# Nearest to has: thor, suet, juggalo, diuretics, tajiks, hating, longitudinal, incompleteness,
# Nearest to so: eliminate, frizer, would, nepheline, citigroup, franciscans, falling, manufactured,
# Nearest to a: only, amuck, enthusiasts, gradius, noin, lightweight, neh, s,
# Nearest to two: five, nine, six, eight, july, zero, hao, acres,
# Nearest to about: wichita, biro, observations, telophase, wogan, heralds, tilted, diameter,
# Nearest to also: primary, multiples, neighbourhood, terms, feeder, aromatics, sponsorship, cytology,
# Nearest to active: warangal, smugglers, supersede, kabir, sejanus, governors, manassas, argue,
# Nearest to channel: dhcp, cooling, flint, pci, likenesses, nutrition, segundo, fujita,
# Nearest to orthodox: possessors, tambalacoque, orthodoxy, catechism, monasteries, oyly, beheld, bellevue,
# Nearest to mean: polyhedron, approach, akhmad, dem, mbeki, senussi, recursive, keyed,
# Nearest to stage: petri, bittersweet, quaternion, shingles, credited, free, screenplays, predatory,
# Nearest to pope: vita, deter, enthusiasms, franck, kara, weert, tie, battle,
# Nearest to discovered: opposites, pelagius, mattel, invincible, cohen, nanaimo, astray, overran,
# Nearest to ocean: tanzania, nta, harbour, bornholm, mexico, intelsat, sewage, shusui,
# Epoch 3/15 Iteration: 10100 Avg. Training loss: 4.2189 0.0387 sec/batch
# Epoch 3/15 Iteration: 10200 Avg. Training loss: 4.2314 0.0378 sec/batch
# Epoch 3/15 Iteration: 10300 Avg. Training loss: 4.2246 0.0377 sec/batch
# Epoch 3/15 Iteration: 10400 Avg. Training loss: 4.0978 0.0378 sec/batch
# Epoch 3/15 Iteration: 10500 Avg. Training loss: 4.1672 0.0377 sec/batch
# Epoch 3/15 Iteration: 10600 Avg. Training loss: 4.1531 0.0377 sec/batch
# Epoch 3/15 Iteration: 10700 Avg. Training loss: 4.1342 0.0375 sec/batch
# Epoch 3/15 Iteration: 10800 Avg. Training loss: 4.1666 0.0377 sec/batch
# Epoch 3/15 Iteration: 10900 Avg. Training loss: 4.2094 0.0375 sec/batch
# Epoch 3/15 Iteration: 11000 Avg. Training loss: 4.1654 0.0377 sec/batch
# Nearest to who: dominator, apostolic, whip, natives, milky, fida, would, miraculous,
# Nearest to history: panoramas, psychometric, documents, qam, percentile, paragraphs, supermanica, fails,
# Nearest to has: thor, suet, juggalo, hating, incompleteness, longitudinal, diuretics, believed,
# Nearest to so: eliminate, would, franciscans, frizer, nepheline, falling, citigroup, recuperate,
# Nearest to a: only, neh, i, noin, enthusiasts, equitable, suppose, gradius,
# Nearest to two: five, six, nine, eight, three, zero, july, trotter,
# Nearest to about: wichita, observations, biro, telophase, tilted, wogan, heralds, hingis,
# Nearest to also: primary, multiples, terms, cytology, draw, aromatics, starches, neighbourhood,
# Nearest to active: warangal, smugglers, supersede, kabir, governors, plywood, crean, manassas,
# Nearest to channel: dhcp, likenesses, segundo, pci, flint, nutrition, broadcasts, shred,
# Nearest to orthodox: possessors, tambalacoque, orthodoxy, catechism, monasteries, oyly, bellevue, sanctified,
# Nearest to mean: polyhedron, approach, mbeki, dem, amounts, akhmad, everquest, keyed,
# Nearest to stage: petri, bittersweet, quaternion, shingles, free, arlo, credited, predatory,
# Nearest to pope: deter, vita, enthusiasms, kara, bishops, franck, alexandria, weert,
# Nearest to discovered: opposites, pelagius, mattel, repulsive, invincible, astray, nanaimo, prediction,
# Nearest to ocean: nta, intelsat, tanzania, bornholm, cover, harbour, shusui, sewage,
# Epoch 3/15 Iteration: 11100 Avg. Training loss: 4.1407 0.0388 sec/batch
# Epoch 3/15 Iteration: 11200 Avg. Training loss: 4.2285 0.0379 sec/batch
# Epoch 3/15 Iteration: 11300 Avg. Training loss: 4.1575 0.0379 sec/batch
# Epoch 3/15 Iteration: 11400 Avg. Training loss: 4.1353 0.0377 sec/batch
# Epoch 3/15 Iteration: 11500 Avg. Training loss: 4.1764 0.0375 sec/batch
# Epoch 3/15 Iteration: 11600 Avg. Training loss: 4.1880 0.0377 sec/batch
# Epoch 3/15 Iteration: 11700 Avg. Training loss: 4.1919 0.0377 sec/batch
# Epoch 3/15 Iteration: 11800 Avg. Training loss: 4.1683 0.0377 sec/batch
# Epoch 3/15 Iteration: 11900 Avg. Training loss: 4.1255 0.0378 sec/batch
# Epoch 3/15 Iteration: 12000 Avg. Training loss: 4.1495 0.0378 sec/batch
# Nearest to who: dominator, apostolic, fida, natives, whip, milky, would, semblance,
# Nearest to history: panoramas, psychometric, paragraphs, percentile, documents, scandinavians, refutations, qam,
# Nearest to has: thor, suet, juggalo, incompleteness, hating, methylated, longitudinal, diuretics,
# Nearest to so: eliminate, franciscans, falling, would, frizer, nepheline, gaited, citigroup,
# Nearest to a: only, neh, poincar, enthusiasts, s, gcl, this, nomological,
# Nearest to two: five, nine, eight, six, zero, three, july, one,
# Nearest to about: observations, wichita, telophase, biro, heralds, wogan, hingis, eclectic,
# Nearest to also: primary, multiples, terms, cytology, draw, neighbourhood, aromatics, starches,
# Nearest to active: warangal, supersede, smugglers, plywood, governors, kabir, illawarra, manassas,
# Nearest to channel: dhcp, segundo, likenesses, broadcasts, flint, pci, cooling, nutrition,
# Nearest to orthodox: orthodoxy, possessors, tambalacoque, monasteries, catechism, iom, abrogate, oyly,
# Nearest to mean: polyhedron, approach, akhmad, marsupial, mbeki, keyed, forgiveness, amounts,
# Nearest to stage: petri, bittersweet, quaternion, shingles, screenplays, free, credited, predatory,
# Nearest to pope: vita, deter, kara, franck, enthusiasms, alexandria, tie, pisan,
# Nearest to discovered: opposites, mattel, prediction, pelagius, repulsive, nanaimo, invincible, astray,
# Nearest to ocean: intelsat, tanzania, bornholm, nta, cover, sewage, geertz, shusui,
# Epoch 3/15 Iteration: 12100 Avg. Training loss: 4.1861 0.0388 sec/batch
# Epoch 3/15 Iteration: 12200 Avg. Training loss: 4.1460 0.0378 sec/batch
# Epoch 3/15 Iteration: 12300 Avg. Training loss: 4.1670 0.0376 sec/batch
# Epoch 3/15 Iteration: 12400 Avg. Training loss: 4.1815 0.0377 sec/batch
# Epoch 3/15 Iteration: 12500 Avg. Training loss: 4.1324 0.0378 sec/batch
# Epoch 3/15 Iteration: 12600 Avg. Training loss: 4.1288 0.0377 sec/batch
# Epoch 3/15 Iteration: 12700 Avg. Training loss: 4.1604 0.0377 sec/batch
# Epoch 3/15 Iteration: 12800 Avg. Training loss: 4.1359 0.0379 sec/batch
# Epoch 3/15 Iteration: 12900 Avg. Training loss: 4.1994 0.0379 sec/batch
# Epoch 3/15 Iteration: 13000 Avg. Training loss: 4.1722 0.0377 sec/batch
# Nearest to who: dominator, apostolic, natives, fida, whip, milky, faction, would,
# Nearest to history: psychometric, panoramas, routledge, vols, documents, scandinavians, paragraphs, kierkegaard,
# Nearest to has: thor, juggalo, hating, suet, incompleteness, longitudinal, diuretics, tajiks,
# Nearest to so: eliminate, franciscans, would, rosario, falling, frizer, nepheline, telemachus,
# Nearest to a: neh, only, i, s, peacefully, amuck, helen, the,
# Nearest to two: five, nine, eight, six, zero, july, one, three,
# Nearest to about: wichita, observations, wogan, hingis, bisexual, telophase, eclectic, heralds,
# Nearest to also: primary, multiples, neighbourhood, cytology, terms, starches, bolger, scriptores,
# Nearest to active: warangal, smugglers, supersede, governors, plywood, illawarra, crean, musketeers,
# Nearest to channel: dhcp, pci, broadcasts, cooling, likenesses, flint, interleave, nutrition,
# Nearest to orthodox: possessors, tambalacoque, orthodoxy, deviates, iom, bellevue, monasteries, beheld,
# Nearest to mean: polyhedron, akhmad, marsupial, keyed, approach, mbeki, disjunction, topographic,
# Nearest to stage: petri, bittersweet, quaternion, shingles, screenplays, free, merchandising, predatory,
# Nearest to pope: vita, deter, pisan, franck, enthusiasms, tie, kara, seven,
# Nearest to discovered: opposites, nanaimo, prediction, pelagius, astray, overran, cohen, repulsive,
# Nearest to ocean: intelsat, bornholm, cover, tanzania, nta, capricorn, geertz, shusui,
# Epoch 3/15 Iteration: 13100 Avg. Training loss: 4.2104 0.0388 sec/batch
# Epoch 3/15 Iteration: 13200 Avg. Training loss: 4.1127 0.0376 sec/batch
# Epoch 3/15 Iteration: 13300 Avg. Training loss: 4.1236 0.0375 sec/batch
# Epoch 3/15 Iteration: 13400 Avg. Training loss: 4.1396 0.0375 sec/batch
# Epoch 3/15 Iteration: 13500 Avg. Training loss: 4.0088 0.0376 sec/batch
# Epoch 3/15 Iteration: 13600 Avg. Training loss: 4.1140 0.0379 sec/batch
# Epoch 3/15 Iteration: 13700 Avg. Training loss: 4.1679 0.0377 sec/batch
# Epoch 3/15 Iteration: 13800 Avg. Training loss: 4.1282 0.0376 sec/batch
# Epoch 4/15 Iteration: 13900 Avg. Training loss: 4.1566 0.0079 sec/batch
# Epoch 4/15 Iteration: 14000 Avg. Training loss: 4.0961 0.0378 sec/batch
# Nearest to who: dominator, natives, apostolic, whip, fida, milky, faction, semblance,
# Nearest to history: panoramas, psychometric, routledge, percentile, paragraphs, documents, scandinavians, vols,
# Nearest to has: thor, suet, juggalo, longitudinal, diuretics, hating, decade, hei,
# Nearest to so: eliminate, would, franciscans, frizer, nepheline, harmful, stibitz, citigroup,
# Nearest to a: only, gcl, s, neh, i, special, amuck, enthusiasts,
# Nearest to two: five, nine, zero, eight, six, three, four, one,
# Nearest to about: wichita, observations, bisexual, wogan, hingis, find, phenomenology, eclectic,
# Nearest to also: multiples, primary, neighbourhood, terms, cytology, amigos, zone, sponsorship,
# Nearest to active: warangal, smugglers, supersede, marshals, governors, crean, plywood, illawarra,
# Nearest to channel: dhcp, broadcasts, likenesses, flint, pci, segundo, cooling, shred,
# Nearest to orthodox: possessors, tambalacoque, orthodoxy, iom, bellevue, deviates, monasteries, envelope,
# Nearest to mean: polyhedron, approach, generalized, marsupial, dem, akhmad, mbeki, everquest,
# Nearest to stage: petri, bittersweet, shingles, quaternion, free, fallout, screenplays, predatory,
# Nearest to pope: deter, pisan, franck, vita, tie, enthusiasms, weert, battle,
# Nearest to discovered: opposites, repulsive, recombine, nanaimo, invincible, pelagius, prediction, fiddlers,
# Nearest to ocean: intelsat, bornholm, subphylum, tanzania, nta, geertz, cover, shusui,
# Epoch 4/15 Iteration: 14100 Avg. Training loss: 4.0638 0.0388 sec/batch
# Epoch 4/15 Iteration: 14200 Avg. Training loss: 4.0495 0.0378 sec/batch
# Epoch 4/15 Iteration: 14300 Avg. Training loss: 4.0756 0.0378 sec/batch
# Epoch 4/15 Iteration: 14400 Avg. Training loss: 4.0399 0.0377 sec/batch
# Epoch 4/15 Iteration: 14500 Avg. Training loss: 4.0364 0.0378 sec/batch
# Epoch 4/15 Iteration: 14600 Avg. Training loss: 4.0056 0.0376 sec/batch
# Epoch 4/15 Iteration: 14700 Avg. Training loss: 4.0939 0.0375 sec/batch
# Epoch 4/15 Iteration: 14800 Avg. Training loss: 4.0540 0.0376 sec/batch
# Epoch 4/15 Iteration: 14900 Avg. Training loss: 4.1073 0.0378 sec/batch
# Epoch 4/15 Iteration: 15000 Avg. Training loss: 4.0448 0.0377 sec/batch
# Nearest to who: dominator, natives, apostolic, whip, milky, fida, faction, semblance,
# Nearest to history: panoramas, routledge, psychometric, scandinavians, paragraphs, supermanica, percentile, kierkegaard,
# Nearest to has: thor, suet, juggalo, decade, hating, methylated, diuretics, longitudinal,
# Nearest to so: eliminate, franciscans, would, single, frizer, falling, lollard, nepheline,
# Nearest to a: only, the, gcl, this, neh, special, i, amuck,
# Nearest to two: five, eight, zero, nine, six, three, july, one,
# Nearest to about: wichita, observations, wogan, bisexual, heralds, diameter, news, eclectic,
# Nearest to also: multiples, primary, terms, cytology, neighbourhood, scriptores, sponsorship, starches,
# Nearest to active: warangal, supersede, smugglers, plywood, glenn, marshals, schreiber, manassas,
# Nearest to channel: dhcp, broadcasts, pci, likenesses, shred, segundo, possible, cooling,
# Nearest to orthodox: possessors, orthodoxy, tambalacoque, abrogate, bellevue, deviates, beheld, iom,
# Nearest to mean: polyhedron, marsupial, profane, mbeki, approach, elevations, dem, prevalence,
# Nearest to stage: petri, shingles, bittersweet, woese, fallout, free, quaternion, predatory,
# Nearest to pope: vita, pisan, deter, franck, bishops, viii, weert, battle,
# Nearest to discovered: opposites, repulsive, pelagius, recombine, nanaimo, prediction, fiddlers, cumulative,
# Nearest to ocean: intelsat, bornholm, subphylum, capricorn, shusui, geertz, nta, domain,
# Epoch 4/15 Iteration: 15100 Avg. Training loss: 4.0085 0.0390 sec/batch
# Epoch 4/15 Iteration: 15200 Avg. Training loss: 4.0447 0.0377 sec/batch
# Epoch 4/15 Iteration: 15300 Avg. Training loss: 3.9897 0.0374 sec/batch
# Epoch 4/15 Iteration: 15400 Avg. Training loss: 4.0229 0.0376 sec/batch
# Epoch 4/15 Iteration: 15500 Avg. Training loss: 4.0579 0.0377 sec/batch
# Epoch 4/15 Iteration: 15600 Avg. Training loss: 4.0295 0.0375 sec/batch
# Epoch 4/15 Iteration: 15700 Avg. Training loss: 4.0631 0.0377 sec/batch
# Epoch 4/15 Iteration: 15800 Avg. Training loss: 4.0775 0.0377 sec/batch
# Epoch 4/15 Iteration: 15900 Avg. Training loss: 4.0130 0.0379 sec/batch
# Epoch 4/15 Iteration: 16000 Avg. Training loss: 4.0369 0.0377 sec/batch
# Nearest to who: dominator, natives, apostolic, whip, milky, fida, semblance, righteous,
# Nearest to history: panoramas, routledge, psychometric, supermanica, paragraphs, percentile, vols, kierkegaard,
# Nearest to has: thor, juggalo, suet, decade, hating, diuretics, believed, monetarist,
# Nearest to so: eliminate, franciscans, would, single, falling, stibitz, lollard, rosario,
# Nearest to a: only, the, poincar, this, gcl, neh, form, i,
# Nearest to two: five, nine, zero, eight, six, three, one, four,
# Nearest to about: wichita, observations, wogan, phenomenology, diameter, find, colson, eclectic,
# Nearest to also: multiples, primary, cytology, terms, scriptores, starches, amigos, norah,
# Nearest to active: warangal, supersede, smugglers, plywood, glenn, schreiber, illawarra, governors,
# Nearest to channel: dhcp, broadcasts, pci, flint, cafes, segundo, likenesses, fujita,
# Nearest to orthodox: orthodoxy, possessors, aristobulus, deviates, constantinopolitan, abrogate, catechism, tambalacoque,
# Nearest to mean: polyhedron, marsupial, profane, prevalence, approach, elevations, akhmad, commotion,
# Nearest to stage: petri, shingles, quaternion, fallout, free, woese, bittersweet, venues,
# Nearest to pope: vita, pisan, deter, bishops, battle, kara, alexandria, franck,
# Nearest to discovered: opposites, repulsive, recombine, pelagius, prediction, fiddlers, cohen, nanaimo,
# Nearest to ocean: intelsat, subphylum, cover, bornholm, capricorn, shusui, sewage, nta,
# Epoch 4/15 Iteration: 16100 Avg. Training loss: 4.0444 0.0387 sec/batch
# Epoch 4/15 Iteration: 16200 Avg. Training loss: 4.0801 0.0378 sec/batch
# Epoch 4/15 Iteration: 16300 Avg. Training loss: 4.0436 0.0377 sec/batch
# Epoch 4/15 Iteration: 16400 Avg. Training loss: 4.0461 0.0376 sec/batch
# Epoch 4/15 Iteration: 16500 Avg. Training loss: 4.0818 0.0378 sec/batch
# Epoch 4/15 Iteration: 16600 Avg. Training loss: 4.0015 0.0378 sec/batch
# Epoch 4/15 Iteration: 16700 Avg. Training loss: 4.0429 0.0376 sec/batch
# Epoch 4/15 Iteration: 16800 Avg. Training loss: 4.0597 0.0376 sec/batch
# Epoch 4/15 Iteration: 16900 Avg. Training loss: 4.0524 0.0378 sec/batch
# Epoch 4/15 Iteration: 17000 Avg. Training loss: 4.0473 0.0378 sec/batch
# Nearest to who: dominator, apostolic, natives, fida, semblance, whip, milky, pashtuns,
# Nearest to history: panoramas, psychometric, routledge, supermanica, scandinavians, world, paragraphs, percentile,
# Nearest to has: thor, juggalo, suet, hating, incompleteness, interpreting, gigabit, yar,
# Nearest to so: eliminate, franciscans, would, rosario, falling, single, citigroup, meuse,
# Nearest to a: only, the, this, neh, s, dah, form, gcl,
# Nearest to two: five, zero, eight, nine, six, three, one, four,
# Nearest to about: wichita, observations, wogan, bisexual, news, hingis, eclectic, find,
# Nearest to also: multiples, primary, scriptores, cytology, lombardic, neighbourhood, amigos, starches,
# Nearest to active: warangal, supersede, glenn, marshals, smugglers, plywood, manassas, schreiber,
# Nearest to channel: dhcp, broadcasts, pci, segundo, cafes, nhra, likenesses, fujita,
# Nearest to orthodox: orthodoxy, possessors, deviates, constantinopolitan, iom, aristobulus, bivalent, tambalacoque,
# Nearest to mean: polyhedron, prevalence, marsupial, profane, elevations, approach, topographic, akhmad,
# Nearest to stage: petri, shingles, quaternion, woese, screenplays, venues, predatory, fallout,
# Nearest to pope: pisan, vita, bishops, deter, battle, tie, weert, kara,
# Nearest to discovered: recombine, opposites, repulsive, pelagius, prediction, nanaimo, scion, fiddlers,
# Nearest to ocean: intelsat, cover, bornholm, subphylum, geertz, capricorn, shusui, nta,
# Epoch 4/15 Iteration: 17100 Avg. Training loss: 4.0136 0.0389 sec/batch
# Epoch 4/15 Iteration: 17200 Avg. Training loss: 3.9817 0.0376 sec/batch
# Epoch 4/15 Iteration: 17300 Avg. Training loss: 4.0101 0.0376 sec/batch
# Epoch 4/15 Iteration: 17400 Avg. Training loss: 4.0594 0.0379 sec/batch
# Epoch 4/15 Iteration: 17500 Avg. Training loss: 4.0582 0.0380 sec/batch
# Epoch 4/15 Iteration: 17600 Avg. Training loss: 4.1200 0.0378 sec/batch
# Epoch 4/15 Iteration: 17700 Avg. Training loss: 4.1307 0.0376 sec/batch
# Epoch 4/15 Iteration: 17800 Avg. Training loss: 3.9989 0.0379 sec/batch
# Epoch 4/15 Iteration: 17900 Avg. Training loss: 4.0268 0.0376 sec/batch
# Epoch 4/15 Iteration: 18000 Avg. Training loss: 4.0651 0.0376 sec/batch
# Nearest to who: dominator, natives, apostolic, whip, semblance, milky, fida, lombardic,
# Nearest to history: panoramas, routledge, psychometric, supermanica, percentile, paragraphs, eratosthenes, vols,
# Nearest to has: thor, suet, juggalo, seconds, hating, biome, tongan, believed,
# Nearest to so: eliminate, franciscans, single, would, falling, nepheline, frizer, harmful,
# Nearest to a: the, only, this, s, gcl, neh, form, poincar,
# Nearest to two: five, zero, eight, nine, three, six, four, one,
# Nearest to about: wichita, observations, wogan, news, find, bisexual, hingis, oa,
# Nearest to also: multiples, primary, urban, amigos, cytology, scriptores, norah, starches,
# Nearest to active: warangal, supersede, marshals, glenn, schreiber, illawarra, smugglers, manassas,
# Nearest to channel: dhcp, broadcasts, cafes, pci, interleave, segundo, fujita, supercup,
# Nearest to orthodox: orthodoxy, possessors, deviates, constantinopolitan, bellevue, iom, aristobulus, tambalacoque,
# Nearest to mean: polyhedron, prevalence, profane, elevations, hackney, akhmad, keyed, marsupial,
# Nearest to stage: petri, shingles, venues, woese, fallout, predatory, screenplays, bittersweet,
# Nearest to pope: pisan, vita, battle, franck, bishops, weert, viii, benedict,
# Nearest to discovered: recombine, opposites, repulsive, pelagius, glamorgan, nanaimo, fiddlers, overran,
# Nearest to ocean: intelsat, bornholm, cover, subphylum, geertz, shusui, domain, capricorn,
# Epoch 4/15 Iteration: 18100 Avg. Training loss: 3.9719 0.0389 sec/batch
# Epoch 4/15 Iteration: 18200 Avg. Training loss: 4.0328 0.0378 sec/batch
# Epoch 4/15 Iteration: 18300 Avg. Training loss: 4.0340 0.0377 sec/batch
# Epoch 4/15 Iteration: 18400 Avg. Training loss: 4.0119 0.0375 sec/batch
# Epoch 4/15 Iteration: 18500 Avg. Training loss: 4.0711 0.0378 sec/batch
# Epoch 5/15 Iteration: 18600 Avg. Training loss: 4.0273 0.0354 sec/batch
# Epoch 5/15 Iteration: 18700 Avg. Training loss: 4.0011 0.0378 sec/batch
# Epoch 5/15 Iteration: 18800 Avg. Training loss: 3.9720 0.0378 sec/batch
# Epoch 5/15 Iteration: 18900 Avg. Training loss: 3.9817 0.0378 sec/batch
# Epoch 5/15 Iteration: 19000 Avg. Training loss: 3.9121 0.0377 sec/batch
# Nearest to who: dominator, natives, apostolic, logician, milky, semblance, pashtuns, fida,
# Nearest to history: panoramas, routledge, psychometric, percentile, supermanica, vols, paragraphs, eratosthenes,
# Nearest to has: thor, suet, juggalo, honorary, hating, interpreting, decade, diuretics,
# Nearest to so: eliminate, would, franciscans, nepheline, single, harmful, frizer, falling,
# Nearest to a: the, only, this, gcl, s, of, combinatorial, poincar,
# Nearest to two: five, zero, eight, nine, three, six, one, four,
# Nearest to about: wichita, news, find, observations, wogan, diameter, bisexual, phenomenology,
# Nearest to also: multiples, primary, cytology, quadriceps, venous, amigos, duchamp, scriptores,
# Nearest to active: warangal, marshals, supersede, glenn, schreiber, smugglers, illawarra, manassas,
# Nearest to channel: dhcp, broadcasts, pci, cafes, interleave, bcd, brindle, segundo,
# Nearest to orthodox: orthodoxy, possessors, iom, truro, constantinopolitan, bellevue, abrogate, aristobulus,
# Nearest to mean: polyhedron, prevalence, elevations, profane, commotion, akhmad, mbeki, metrication,
# Nearest to stage: petri, venues, predatory, woese, fallout, shingles, quaternion, screenplays,
# Nearest to pope: pisan, battle, vita, bishops, franck, weert, benedict, tie,
# Nearest to discovered: recombine, pelagius, opposites, repulsive, overran, nanaimo, invincible, fiddlers,
# Nearest to ocean: intelsat, bornholm, cover, subphylum, capricorn, shusui, tanzania, domain,
# Epoch 5/15 Iteration: 19100 Avg. Training loss: 3.9899 0.0389 sec/batch
# Epoch 5/15 Iteration: 19200 Avg. Training loss: 3.9409 0.0378 sec/batch
# Epoch 5/15 Iteration: 19300 Avg. Training loss: 3.9898 0.0376 sec/batch
# Epoch 5/15 Iteration: 19400 Avg. Training loss: 3.9905 0.0376 sec/batch
# Epoch 5/15 Iteration: 19500 Avg. Training loss: 3.9874 0.0378 sec/batch
# Epoch 5/15 Iteration: 19600 Avg. Training loss: 3.9693 0.0378 sec/batch
# Epoch 5/15 Iteration: 19700 Avg. Training loss: 3.8896 0.0378 sec/batch
# Epoch 5/15 Iteration: 19800 Avg. Training loss: 3.9756 0.0377 sec/batch
# Epoch 5/15 Iteration: 19900 Avg. Training loss: 3.9197 0.0377 sec/batch
# Epoch 5/15 Iteration: 20000 Avg. Training loss: 3.9459 0.0377 sec/batch
# Nearest to who: dominator, natives, apostolic, semblance, whip, fida, fp, not,
# Nearest to history: panoramas, psychometric, routledge, supermanica, percentile, paragraphs, timelines, world,
# Nearest to has: thor, suet, is, the, juggalo, hating, decade, of,
# Nearest to so: eliminate, franciscans, would, falling, single, nepheline, you, lipi,
# Nearest to a: the, only, this, of, gcl, consequently, form, s,
# Nearest to two: five, zero, eight, nine, three, six, one, four,
# Nearest to about: wichita, news, wogan, observations, bisexual, find, diameter, eclectic,
# Nearest to also: multiples, primary, cytology, urban, called, terms, usda, flavored,
# Nearest to active: warangal, marshals, supersede, glenn, schreiber, plywood, illawarra, manassas,
# Nearest to channel: broadcasts, dhcp, pci, bcd, cafes, fujita, cjd, npc,
# Nearest to orthodox: orthodoxy, possessors, truro, iom, constantinopolitan, beheld, tambalacoque, deviates,
# Nearest to mean: prevalence, profane, polyhedron, elevations, commotion, amounts, marsupial, tripitaka,
# Nearest to stage: venues, petri, predatory, woese, fallout, shingles, screenplays, free,
# Nearest to pope: pisan, vita, bishops, weert, benedict, popes, battle, deter,
# Nearest to discovered: recombine, pelagius, repulsive, opposites, overran, cohen, prediction, cumulative,
# Nearest to ocean: intelsat, subphylum, bornholm, domain, cover, shusui, geertz, capricorn,
# Epoch 5/15 Iteration: 20100 Avg. Training loss: 3.9941 0.0389 sec/batch
# Epoch 5/15 Iteration: 20200 Avg. Training loss: 3.9732 0.0377 sec/batch
# Epoch 5/15 Iteration: 20300 Avg. Training loss: 3.9616 0.0377 sec/batch
# Epoch 5/15 Iteration: 20400 Avg. Training loss: 3.9893 0.0378 sec/batch
# Epoch 5/15 Iteration: 20500 Avg. Training loss: 4.0350 0.0378 sec/batch
# Epoch 5/15 Iteration: 20600 Avg. Training loss: 3.9130 0.0377 sec/batch
# Epoch 5/15 Iteration: 20700 Avg. Training loss: 3.9815 0.0378 sec/batch
# Epoch 5/15 Iteration: 20800 Avg. Training loss: 3.9722 0.0377 sec/batch
# Epoch 5/15 Iteration: 20900 Avg. Training loss: 3.9842 0.0379 sec/batch
# Epoch 5/15 Iteration: 21000 Avg. Training loss: 3.9843 0.0376 sec/batch
# Nearest to who: dominator, semblance, natives, apostolic, not, whip, fida, pashtuns,
# Nearest to history: panoramas, routledge, supermanica, psychometric, percentile, guelfs, timelines, paragraphs,
# Nearest to has: thor, the, decade, suet, juggalo, hating, interpreting, upc,
# Nearest to so: eliminate, franciscans, you, would, single, nepheline, falling, lipi,
# Nearest to a: the, only, this, of, s, gcl, poincar, form,
# Nearest to two: five, zero, eight, nine, one, six, three, four,
# Nearest to about: news, wichita, observations, wogan, eclectic, find, heralds, bisexual,
# Nearest to also: multiples, called, primary, lombardic, scriptores, amigos, flavored, is,
# Nearest to active: warangal, marshals, supersede, glenn, schreiber, illawarra, plywood, tagalog,
# Nearest to channel: broadcasts, dhcp, pci, bcd, cafes, cjd, fujita, nhra,
# Nearest to orthodox: orthodoxy, constantinopolitan, tambalacoque, possessors, iom, truro, deviates, beheld,
# Nearest to mean: prevalence, profane, marsupial, commotion, abbreviations, elevations, coptic, tripitaka,
# Nearest to stage: venues, predatory, woese, petri, screenplays, quaternion, free, shingles,
# Nearest to pope: pisan, vita, benedict, bishops, franck, tie, battle, reader,
# Nearest to discovered: recombine, overran, pelagius, repulsive, cohen, prediction, opposites, cumulative,
# Nearest to ocean: intelsat, subphylum, cover, bornholm, shusui, nta, ithilien, geertz,
# Epoch 5/15 Iteration: 21100 Avg. Training loss: 3.9956 0.0390 sec/batch
# Epoch 5/15 Iteration: 21200 Avg. Training loss: 3.9915 0.0377 sec/batch
# Epoch 5/15 Iteration: 21300 Avg. Training loss: 3.9596 0.0377 sec/batch
# Epoch 5/15 Iteration: 21400 Avg. Training loss: 3.9962 0.0377 sec/batch
# Epoch 5/15 Iteration: 21500 Avg. Training loss: 3.9883 0.0378 sec/batch
# Epoch 5/15 Iteration: 21600 Avg. Training loss: 3.9709 0.0378 sec/batch
# Epoch 5/15 Iteration: 21700 Avg. Training loss: 3.9650 0.0376 sec/batch
# Epoch 5/15 Iteration: 21800 Avg. Training loss: 3.9463 0.0376 sec/batch
# Epoch 5/15 Iteration: 21900 Avg. Training loss: 3.9630 0.0376 sec/batch
# Epoch 5/15 Iteration: 22000 Avg. Training loss: 4.0113 0.0379 sec/batch
# Nearest to who: dominator, apostolic, natives, semblance, fida, pashtuns, not, lombardic,
# Nearest to history: panoramas, routledge, psychometric, supermanica, world, timelines, britanniae, prehistory,
# Nearest to has: thor, the, of, suet, juggalo, interpreting, decade, is,
# Nearest to so: eliminate, franciscans, nepheline, would, you, citigroup, single, signed,
# Nearest to a: the, this, only, of, s, known, an, form,
# Nearest to two: five, zero, eight, nine, three, six, one, four,
# Nearest to about: news, observations, bisexual, wichita, find, mestizo, latest, heralds,
# Nearest to also: multiples, primary, scriptores, called, terms, cytology, is, venous,
# Nearest to active: warangal, marshals, supersede, glenn, be, manassas, illawarra, schreiber,
# Nearest to channel: broadcasts, dhcp, pci, bcd, cafes, csl, interleave, fujita,
# Nearest to orthodox: orthodoxy, constantinopolitan, possessors, beheld, tambalacoque, deviates, iom, aristobulus,
# Nearest to mean: prevalence, polyhedron, generalized, profane, topographic, abbreviations, everquest, marsupial,
# Nearest to stage: venues, predatory, woese, petri, quaternion, screenplays, infanticide, free,
# Nearest to pope: pisan, vita, benedict, deter, battle, franck, reader, bishops,
# Nearest to discovered: recombine, overran, pelagius, opposites, repulsive, cohen, fiddlers, cumulative,
# Nearest to ocean: intelsat, cover, subphylum, bornholm, domain, shusui, nta, ithilien,
# Epoch 5/15 Iteration: 22100 Avg. Training loss: 3.9611 0.0390 sec/batch
# ...
# Epoch 14/15 Iteration: 61500 Avg. Training loss: 3.7356 0.0377 sec/batch
# Epoch 14/15 Iteration: 61600 Avg. Training loss: 3.6661 0.0374 sec/batch
# Epoch 14/15 Iteration: 61700 Avg. Training loss: 3.7217 0.0376 sec/batch
# Epoch 14/15 Iteration: 61800 Avg. Training loss: 3.8009 0.0378 sec/batch
# Epoch 14/15 Iteration: 61900 Avg. Training loss: 3.7570 0.0376 sec/batch
# Epoch 14/15 Iteration: 62000 Avg. Training loss: 3.7341 0.0376 sec/batch
# Nearest to who: to, not, people, might, whip, frustrated, and, own,
# Nearest to history: timelines, see, links, of, external, routledge, article, articles,
# Nearest to has: been, the, is, of, have, as, and, recently,
# Nearest to so: be, into, they, happens, could, katy, single, would,
# Nearest to a: the, of, to, is, an, as, this, and,
# Nearest to two: three, five, zero, one, four, eight, nine, six,
# Nearest to about: oldenburg, zero, on, eclectic, know, entertain, for, find,
# Nearest to also: the, in, a, and, of, see, is, called,
# Nearest to active: passive, participle, activated, pia, mira, lcms, marshals, wonderswan,
# Nearest to channel: broadcasts, sensation, isbns, pci, aegean, possesses, tty, lice,
# Nearest to orthodox: orthodoxy, deviates, bellevue, til, painted, industrialization, yugoslav, judaism,
# Nearest to mean: coptic, kola, term, systran, mazes, profane, penises, talk,
# Nearest to stage: venues, infanticide, performed, theater, florida, theatres, perak, snowfalls,
# Nearest to pope: conformity, octahedral, initiator, taint, popes, pisan, innocent, racine,
# Nearest to discovered: named, became, was, fortune, nikolay, cordwainer, glamorgan, refitted,
# Nearest to ocean: brahmi, intelsat, oceans, subphylum, ethernet, squirt, pacific, domain,
# Epoch 14/15 Iteration: 62100 Avg. Training loss: 3.8454 0.0388 sec/batch
# Epoch 14/15 Iteration: 62200 Avg. Training loss: 3.8042 0.0378 sec/batch
# Epoch 14/15 Iteration: 62300 Avg. Training loss: 3.7904 0.0375 sec/batch
# Epoch 14/15 Iteration: 62400 Avg. Training loss: 3.7399 0.0375 sec/batch
# Epoch 14/15 Iteration: 62500 Avg. Training loss: 3.7578 0.0376 sec/batch
# Epoch 14/15 Iteration: 62600 Avg. Training loss: 3.7979 0.0377 sec/batch
# Epoch 14/15 Iteration: 62700 Avg. Training loss: 3.7644 0.0375 sec/batch
# Epoch 14/15 Iteration: 62800 Avg. Training loss: 3.8164 0.0377 sec/batch
# Epoch 14/15 Iteration: 62900 Avg. Training loss: 3.7768 0.0377 sec/batch
# Epoch 14/15 Iteration: 63000 Avg. Training loss: 3.8047 0.0376 sec/batch
# Nearest to who: might, people, not, to, natives, whip, fp, whose,
# Nearest to history: timelines, see, links, routledge, external, of, article, six,
# Nearest to has: been, the, of, recently, is, have, however, it,
# Nearest to so: be, into, happens, katy, like, could, they, would,
# Nearest to a: of, the, to, this, is, an, and, also,
# Nearest to two: zero, three, five, one, four, eight, six, nine,
# Nearest to about: zero, on, oldenburg, five, of, entertain, know, eclectic,
# Nearest to also: the, a, and, of, see, in, is, by,
# Nearest to active: passive, participle, pia, activated, marshals, wonderswan, cleavage, mira,
# Nearest to channel: isbns, pci, sensation, aegean, broadcasts, possesses, accepting, tty,
# Nearest to orthodox: orthodoxy, deviates, bellevue, til, yugoslav, bowling, telophase, industrialization,
# Nearest to mean: coptic, kola, term, systran, compute, mazes, fellows, increases,
# Nearest to stage: venues, infanticide, performed, theater, florida, theatres, perak, mahatma,
# Nearest to pope: conformity, octahedral, pisan, initiator, taint, tuxedo, racine, benedict,
# Nearest to discovered: named, was, became, fortune, nikolay, cordwainer, refitted, cumulative,
# Nearest to ocean: intelsat, brahmi, iceland, ethernet, subphylum, oceans, squirt, mtv,
# Epoch 14/15 Iteration: 63100 Avg. Training loss: 3.7883 0.0389 sec/batch
# Epoch 14/15 Iteration: 63200 Avg. Training loss: 3.7518 0.0377 sec/batch
# Epoch 14/15 Iteration: 63300 Avg. Training loss: 3.7902 0.0376 sec/batch
# Epoch 14/15 Iteration: 63400 Avg. Training loss: 3.7715 0.0376 sec/batch
# Epoch 14/15 Iteration: 63500 Avg. Training loss: 3.7801 0.0376 sec/batch
# Epoch 14/15 Iteration: 63600 Avg. Training loss: 3.7770 0.0377 sec/batch
# Epoch 14/15 Iteration: 63700 Avg. Training loss: 3.7732 0.0380 sec/batch
# Epoch 14/15 Iteration: 63800 Avg. Training loss: 3.8490 0.0378 sec/batch
# Epoch 14/15 Iteration: 63900 Avg. Training loss: 3.8299 0.0376 sec/batch
# Epoch 14/15 Iteration: 64000 Avg. Training loss: 3.8115 0.0375 sec/batch
# Nearest to who: people, to, natives, might, whip, not, frustrated, discouraged,
# Nearest to history: timelines, links, routledge, see, external, vintage, of, timeline,
# Nearest to has: been, the, of, is, as, s, have, since,
# Nearest to so: into, be, they, happens, katy, would, could, only,
# Nearest to a: the, of, to, this, an, and, for, as,
# Nearest to two: zero, five, three, one, four, eight, six, nine,
# Nearest to about: zero, on, oldenburg, five, know, for, one, eclectic,
# Nearest to also: the, of, and, a, see, in, an, is,
# Nearest to active: passive, participle, pia, marshals, during, activated, wonderswan, mira,
# Nearest to channel: isbns, aegean, possesses, sensation, pci, broadcasts, accepting, npc,
# Nearest to orthodox: orthodoxy, deviates, bellevue, judaism, til, painted, bowling, rahxephon,
# Nearest to mean: coptic, compute, kola, systran, term, mazes, fellows, penises,
# Nearest to stage: venues, infanticide, florida, theater, theatres, performed, perak, interscope,
# Nearest to pope: conformity, octahedral, pisan, initiator, racine, benedict, taint, antibodies,
# Nearest to discovered: named, fortune, became, nikolay, refitted, cordwainer, apparently, cumulative,
# Nearest to ocean: brahmi, intelsat, iceland, indian, ethernet, duddy, subphylum, squirt,
# Epoch 14/15 Iteration: 64100 Avg. Training loss: 3.7882 0.0389 sec/batch
# Epoch 14/15 Iteration: 64200 Avg. Training loss: 3.7110 0.0374 sec/batch
# Epoch 14/15 Iteration: 64300 Avg. Training loss: 3.7508 0.0374 sec/batch
# Epoch 14/15 Iteration: 64400 Avg. Training loss: 3.6707 0.0376 sec/batch
# Epoch 14/15 Iteration: 64500 Avg. Training loss: 3.7916 0.0377 sec/batch
# Epoch 14/15 Iteration: 64600 Avg. Training loss: 3.7686 0.0376 sec/batch
# Epoch 14/15 Iteration: 64700 Avg. Training loss: 3.7735 0.0377 sec/batch
# Epoch 15/15 Iteration: 64800 Avg. Training loss: 3.8358 0.0090 sec/batch
# Epoch 15/15 Iteration: 64900 Avg. Training loss: 3.7658 0.0377 sec/batch
# Epoch 15/15 Iteration: 65000 Avg. Training loss: 3.7652 0.0377 sec/batch
# Nearest to who: people, to, might, natives, own, not, was, frustrated,
# Nearest to history: timelines, links, see, routledge, external, vintage, article, articles,
# Nearest to has: been, is, of, the, have, recently, s, and,
# Nearest to so: be, happens, could, would, they, this, into, were,
# Nearest to a: of, the, an, this, to, is, for, and,
# Nearest to two: three, five, zero, four, one, eight, nine, six,
# Nearest to about: zero, oldenburg, on, five, the, know, for, of,
# Nearest to also: a, the, and, in, of, see, an, other,
# Nearest to active: passive, participle, um, pia, mira, marshals, wonderswan, activated,
# Nearest to channel: isbns, possesses, broadcasts, aegean, sensation, pci, accepting, npc,
# Nearest to orthodox: orthodoxy, judaism, deviates, bellevue, til, stillness, industrialization, rahxephon,
# Nearest to mean: coptic, variance, compute, term, towards, hackney, unsurprising, fellows,
# Nearest to stage: venues, infanticide, florida, theatres, performed, theater, perak, snowfalls,
# Nearest to pope: octahedral, conformity, pisan, initiator, racine, tuxedo, popes, felt,
# Nearest to discovered: named, apparently, fortune, became, nikolay, refitted, was, cumulative,
# Nearest to ocean: brahmi, intelsat, indian, iceland, oceans, subphylum, pacific, atlantic,
# Epoch 15/15 Iteration: 65100 Avg. Training loss: 3.7719 0.0391 sec/batch
# Epoch 15/15 Iteration: 65200 Avg. Training loss: 3.7925 0.0376 sec/batch
# Epoch 15/15 Iteration: 65300 Avg. Training loss: 3.7120 0.0377 sec/batch
# Epoch 15/15 Iteration: 65400 Avg. Training loss: 3.7596 0.0377 sec/batch
# Epoch 15/15 Iteration: 65500 Avg. Training loss: 3.7215 0.0376 sec/batch
# Epoch 15/15 Iteration: 65600 Avg. Training loss: 3.7597 0.0375 sec/batch
# Epoch 15/15 Iteration: 65700 Avg. Training loss: 3.7764 0.0376 sec/batch
# Epoch 15/15 Iteration: 65800 Avg. Training loss: 3.8490 0.0379 sec/batch
# Epoch 15/15 Iteration: 65900 Avg. Training loss: 3.7164 0.0377 sec/batch
# Epoch 15/15 Iteration: 66000 Avg. Training loss: 3.6901 0.0376 sec/batch
# Nearest to who: to, people, natives, not, own, might, was, frustrated,
# Nearest to history: see, links, timelines, external, of, routledge, article, timeline,
# Nearest to has: been, of, the, is, have, and, in, as,
# Nearest to so: be, happens, could, into, then, they, katy, would,
# Nearest to a: the, of, to, an, this, for, and, as,
# Nearest to two: three, five, zero, one, four, eight, six, nine,
# Nearest to about: oldenburg, five, zero, on, know, eclectic, observations, entertain,
# Nearest to also: in, see, and, of, the, an, a, is,
# Nearest to active: passive, participle, um, pia, wonderswan, activated, mira, marshals,
# Nearest to channel: isbns, broadcasts, aegean, possesses, pci, sensation, supercup, tty,
# Nearest to orthodox: orthodoxy, deviates, judaism, bellevue, til, stillness, industrialization, bowling,
# Nearest to mean: coptic, variance, profane, term, unsurprising, kola, compute, fellows,
# Nearest to stage: venues, infanticide, theatres, florida, theater, performed, snowfalls, perak,
# Nearest to pope: octahedral, conformity, felt, initiator, tuxedo, pisan, parmenides, popes,
# Nearest to discovered: named, nikolay, was, fortune, refitted, became, apparently, tumors,
# Nearest to ocean: brahmi, intelsat, indian, squirt, iceland, subphylum, pacific, ethernet,
# Epoch 15/15 Iteration: 66100 Avg. Training loss: 3.7568 0.0386 sec/batch
# Epoch 15/15 Iteration: 66200 Avg. Training loss: 3.6594 0.0376 sec/batch
# Epoch 15/15 Iteration: 66300 Avg. Training loss: 3.7284 0.0377 sec/batch
# Epoch 15/15 Iteration: 66400 Avg. Training loss: 3.8109 0.0376 sec/batch
# Epoch 15/15 Iteration: 66500 Avg. Training loss: 3.7433 0.0377 sec/batch
# Epoch 15/15 Iteration: 66600 Avg. Training loss: 3.7426 0.0376 sec/batch
# Epoch 15/15 Iteration: 66700 Avg. Training loss: 3.7902 0.0377 sec/batch
# Epoch 15/15 Iteration: 66800 Avg. Training loss: 3.7709 0.0376 sec/batch
# Epoch 15/15 Iteration: 66900 Avg. Training loss: 3.7514 0.0376 sec/batch
# Epoch 15/15 Iteration: 67000 Avg. Training loss: 3.7542 0.0375 sec/batch
# Nearest to who: to, people, natives, might, not, semblance, frustrated, was,
# Nearest to history: see, timelines, external, links, of, routledge, timeline, throughout,
# Nearest to has: been, of, is, have, the, recently, and, as,
# Nearest to so: be, into, they, this, like, happens, via, bbs,
# Nearest to a: the, of, this, an, to, as, for, in,
# Nearest to two: three, five, zero, four, one, eight, nine, six,
# Nearest to about: oldenburg, on, diameter, observations, eclectic, five, zero, entertain,
# Nearest to also: see, in, and, the, of, a, an, is,
# Nearest to active: passive, participle, pia, activated, mira, um, to, lcms,
# Nearest to channel: isbns, broadcasts, sensation, pci, aegean, possesses, tty, ferry,
# Nearest to orthodox: orthodoxy, deviates, bellevue, judaism, til, geometrically, bowling, patriarchate,
# Nearest to mean: coptic, variance, term, kola, unsurprising, towards, profane, penises,
# Nearest to stage: venues, florida, theatres, infanticide, theater, performed, perak, immortalised,
# Nearest to pope: conformity, octahedral, parmenides, benedict, popes, antibodies, taint, initiator,
# Nearest to discovered: nikolay, was, named, apparently, refitted, fortune, became, cordwainer,
# Nearest to ocean: brahmi, intelsat, indian, iceland, squirt, pacific, subphylum, ethernet,
# Epoch 15/15 Iteration: 67100 Avg. Training loss: 3.7697 0.0388 sec/batch
# Epoch 15/15 Iteration: 67200 Avg. Training loss: 3.8031 0.0377 sec/batch
# Epoch 15/15 Iteration: 67300 Avg. Training loss: 3.7416 0.0375 sec/batch
# Epoch 15/15 Iteration: 67400 Avg. Training loss: 3.7920 0.0377 sec/batch
# Epoch 15/15 Iteration: 67500 Avg. Training loss: 3.7809 0.0377 sec/batch
# Epoch 15/15 Iteration: 67600 Avg. Training loss: 3.7559 0.0376 sec/batch
# Epoch 15/15 Iteration: 67700 Avg. Training loss: 3.7878 0.0378 sec/batch
# Epoch 15/15 Iteration: 67800 Avg. Training loss: 3.7585 0.0376 sec/batch
# Epoch 15/15 Iteration: 67900 Avg. Training loss: 3.7648 0.0377 sec/batch
# Epoch 15/15 Iteration: 68000 Avg. Training loss: 3.7646 0.0376 sec/batch
# Nearest to who: to, not, people, natives, and, was, by, their,
# Nearest to history: of, external, links, timelines, see, timeline, routledge, article,
# Nearest to has: been, the, is, of, have, as, recently, however,
# Nearest to so: be, into, happens, this, they, via, katy, would,
# Nearest to a: the, of, an, to, as, this, s, and,
# Nearest to two: five, zero, three, one, four, eight, six, nine,
# Nearest to about: on, zero, oldenburg, five, one, observations, entertain, of,
# Nearest to also: of, the, and, see, in, a, is, an,
# Nearest to active: passive, participle, wonderswan, activated, pia, mira, countermeasures, marshals,
# Nearest to channel: isbns, broadcasts, pci, sensation, aegean, ferry, tty, supercup,
# Nearest to orthodox: orthodoxy, deviates, judaism, bellevue, til, bridgewater, millarca, rahxephon,
# Nearest to mean: coptic, kola, term, variance, unsurprising, fellows, systran, hackney,
# Nearest to stage: venues, infanticide, theatres, florida, performed, perak, theater, immortalised,
# Nearest to pope: conformity, octahedral, benedict, viii, popes, innocent, taint, anastasius,
# Nearest to discovered: nikolay, was, named, apparently, refitted, fortune, glamorgan, cumulative,
# Nearest to ocean: brahmi, indian, intelsat, iceland, pacific, squirt, subphylum, ethernet,
# Epoch 15/15 Iteration: 68100 Avg. Training loss: 3.7594 0.0388 sec/batch
# Epoch 15/15 Iteration: 68200 Avg. Training loss: 3.7758 0.0375 sec/batch
# Epoch 15/15 Iteration: 68300 Avg. Training loss: 3.8037 0.0377 sec/batch
# Epoch 15/15 Iteration: 68400 Avg. Training loss: 3.8424 0.0380 sec/batch
# Epoch 15/15 Iteration: 68500 Avg. Training loss: 3.8628 0.0377 sec/batch
# Epoch 15/15 Iteration: 68600 Avg. Training loss: 3.8032 0.0374 sec/batch
# Epoch 15/15 Iteration: 68700 Avg. Training loss: 3.7816 0.0378 sec/batch
# Epoch 15/15 Iteration: 68800 Avg. Training loss: 3.7348 0.0376 sec/batch
# Epoch 15/15 Iteration: 68900 Avg. Training loss: 3.7321 0.0376 sec/batch
# Epoch 15/15 Iteration: 69000 Avg. Training loss: 3.6950 0.0375 sec/batch
# Nearest to who: to, people, natives, not, was, he, frustrated, alumni,
# Nearest to history: links, external, timelines, see, of, timeline, routledge, brief,
# Nearest to has: been, of, is, have, the, s, as, recently,
# Nearest to so: be, into, happens, this, they, were, like, bbs,
# Nearest to a: the, of, to, s, as, an, and, this,
# Nearest to two: zero, five, three, one, four, nine, eight, seven,
# Nearest to about: oldenburg, on, zero, five, news, one, of, the,
# Nearest to also: of, in, the, a, and, see, other, for,
# Nearest to active: passive, participle, um, pia, mira, marshals, lcms, wonderswan,
# Nearest to channel: isbns, broadcasts, pci, aegean, sensation, possesses, ferry, npc,
# Nearest to orthodox: orthodoxy, judaism, bellevue, deviates, rahxephon, til, industrialization, millarca,
# Nearest to mean: coptic, variance, term, systran, unsurprising, compute, hackney, fellows,
# Nearest to stage: venues, infanticide, theatres, florida, performed, snowfalls, theater, immortalised,
# Nearest to pope: octahedral, benedict, conformity, viii, popes, anastasius, felt, pisan,
# Nearest to discovered: named, fortune, nikolay, refitted, glamorgan, apparently, was, cordwainer,
# Nearest to ocean: indian, brahmi, intelsat, pacific, iceland, squirt, duddy, ethernet,
# Epoch 15/15 Iteration: 69100 Avg. Training loss: 3.7488 0.0388 sec/batch
# Epoch 15/15 Iteration: 69200 Avg. Training loss: 3.7753 0.0377 sec/batch
# Epoch 15/15 Iteration: 69300 Avg. Training loss: 3.7754 0.0376 sec/batch
# Epoch 15/15 Iteration: 69400 Avg. Training loss: 3.8132 0.0376 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
