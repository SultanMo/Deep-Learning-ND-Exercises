# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

threshold = 1e-5 # from Mikolov et al. NIPS paper
word_count = Counter(int_words)
total_count = len(int_words)
freq = {word: count/total_count for word, count in word_count.items()}
prob = {word: 1 - np.sqrt(threshold/freq[word]) for word in freq}
train_words = [word for word in int_words if prob[word] < random.random()]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''

    random_n = random.randint(1, window_size+1)
    start_idx = idx - random_n if (idx - random_n) > 0 else 0
    end_idx = idx + random_n
    target_words = set(words[start_idx:idx]+ words[idx+1:end_idx+1])
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None])
    labels = tf.placeholder(tf.int32, [None,None])

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 300 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1)) # embedding weight matrix
    embed = tf.nn.embedding_lookup(embedding, inputs) # tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))#  softmax weight matrix
    softmax_b = tf.Variable(tf.zeros(n_vocab))# softmax biases
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 15
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/15 Iteration: 100 Avg. Training loss: 5.7775 0.0392 sec/batch
# Epoch 1/15 Iteration: 200 Avg. Training loss: 5.7082 0.0378 sec/batch
# Epoch 1/15 Iteration: 300 Avg. Training loss: 5.5866 0.0378 sec/batch
# Epoch 1/15 Iteration: 400 Avg. Training loss: 5.7071 0.0377 sec/batch
# Epoch 1/15 Iteration: 500 Avg. Training loss: 5.6199 0.0377 sec/batch
# Epoch 1/15 Iteration: 600 Avg. Training loss: 5.6271 0.0378 sec/batch
# Epoch 1/15 Iteration: 700 Avg. Training loss: 5.6515 0.0377 sec/batch
# Epoch 1/15 Iteration: 800 Avg. Training loss: 5.6878 0.0375 sec/batch
# Epoch 1/15 Iteration: 900 Avg. Training loss: 5.5330 0.0376 sec/batch
# Epoch 1/15 Iteration: 1000 Avg. Training loss: 5.5242 0.0378 sec/batch
# Nearest to their: posteriori, most, challengers, pn, ifr, censuses, transformers, catholicism,
# Nearest to people: dames, feeders, capsized, talk, chats, pooled, monument, homicidal,
# Nearest to th: cuon, decca, accordingly, strontium, disapproval, spotless, steffens, brushed,
# Nearest to or: dealerships, kali, computed, spymaster, unseated, heresy, catastrophism, repeated,
# Nearest to six: effigies, attitudes, intermarried, floats, cretan, churchman, surrounds, fancher,
# Nearest to for: littoral, effect, strict, asch, fitch, lfar, aggression, multiple,
# Nearest to which: lust, ral, truetype, mohamad, ferry, poor, suggestions, greetings,
# Nearest to so: pumice, black, estonian, megiddo, kitts, weeds, nunnery, lebrun,
# Nearest to writers: hyperbole, garp, plethora, decimated, montaigne, tonsils, drabble, tested,
# Nearest to applied: aldous, imagination, theorems, apoplexy, betts, urbina, peckinpah, midyear,
# Nearest to lived: deduced, dared, acyclic, toughest, daily, droste, prof, mannerist,
# Nearest to award: havenco, vukovar, bes, conceived, strau, argues, hopi, simus,
# Nearest to instance: leguizamo, dern, nistru, rsa, wilson, flyweight, dunne, heroics,
# Nearest to event: dodos, casio, xiong, df, eighteen, slower, waging, twin,
# Nearest to rise: assizes, answer, lr, rica, electrolytes, graduation, austro, nonempty,
# Nearest to recorded: explosively, wavelengths, botanicals, xviii, templates, formally, infinitive, masaryk,
# Epoch 1/15 Iteration: 1100 Avg. Training loss: 5.5601 0.0389 sec/batch
# Epoch 1/15 Iteration: 1200 Avg. Training loss: 5.4403 0.0378 sec/batch
# Epoch 1/15 Iteration: 1300 Avg. Training loss: 5.4156 0.0377 sec/batch
# Epoch 1/15 Iteration: 1400 Avg. Training loss: 5.2926 0.0376 sec/batch
# Epoch 1/15 Iteration: 1500 Avg. Training loss: 5.2422 0.0378 sec/batch
# Epoch 1/15 Iteration: 1600 Avg. Training loss: 5.2031 0.0379 sec/batch
# Epoch 1/15 Iteration: 1700 Avg. Training loss: 5.1262 0.0377 sec/batch
# Epoch 1/15 Iteration: 1800 Avg. Training loss: 5.0986 0.0377 sec/batch
# Epoch 1/15 Iteration: 1900 Avg. Training loss: 5.0527 0.0375 sec/batch
# Epoch 1/15 Iteration: 2000 Avg. Training loss: 5.0125 0.0378 sec/batch
# Nearest to their: most, posteriori, catholicism, dimension, challengers, distinguished, pn, ifr,
# Nearest to people: talk, monument, capsized, feeders, eng, distribution, kinks, chats,
# Nearest to th: accordingly, disapproval, decca, removing, steffens, cuon, spotless, whether,
# Nearest to or: computed, repeated, dealerships, kali, spymaster, unseated, mix, catastrophism,
# Nearest to six: attitudes, floats, cretan, intermarried, effigies, reach, churchman, asynchronous,
# Nearest to for: effect, multiple, materials, littoral, strict, fitch, after, aggression,
# Nearest to which: lust, molecular, experiments, varied, ral, poor, ferry, suggestions,
# Nearest to so: black, additional, level, pumice, estonian, topology, radius, oscillating,
# Nearest to writers: plethora, doubts, tested, tonsils, drabble, performances, volunteered, decimated,
# Nearest to applied: aldous, imagination, theorems, got, apoplexy, peckinpah, no, experienced,
# Nearest to lived: deduced, daily, toughest, dared, acyclic, droste, prof, activity,
# Nearest to award: conceived, argues, havenco, vukovar, forgery, towns, deserts, philip,
# Nearest to instance: leguizamo, rsa, wilson, han, missions, dern, enabling, sitar,
# Nearest to event: casio, slower, eighteen, twin, xiong, df, dodos, waging,
# Nearest to rise: answer, graduation, assizes, austro, controlled, electrolytes, purposes, rica,
# Nearest to recorded: formally, explosively, wavelengths, xviii, infinitive, templates, organic, diem,
# Epoch 1/15 Iteration: 2100 Avg. Training loss: 4.9959 0.0388 sec/batch
# Epoch 1/15 Iteration: 2200 Avg. Training loss: 4.9556 0.0377 sec/batch
# Epoch 1/15 Iteration: 2300 Avg. Training loss: 4.9230 0.0378 sec/batch
# Epoch 1/15 Iteration: 2400 Avg. Training loss: 4.9206 0.0378 sec/batch
# Epoch 1/15 Iteration: 2500 Avg. Training loss: 4.8765 0.0376 sec/batch
# Epoch 1/15 Iteration: 2600 Avg. Training loss: 4.8914 0.0379 sec/batch
# Epoch 1/15 Iteration: 2700 Avg. Training loss: 4.8513 0.0378 sec/batch
# Epoch 1/15 Iteration: 2800 Avg. Training loss: 4.8591 0.0378 sec/batch
# Epoch 1/15 Iteration: 2900 Avg. Training loss: 4.8105 0.0378 sec/batch
# Epoch 1/15 Iteration: 3000 Avg. Training loss: 4.8210 0.0377 sec/batch
# Nearest to their: posteriori, most, challengers, ifr, transformers, catholicism, dimension, illustrated,
# Nearest to people: talk, feeders, chats, rowland, eng, pooled, kinks, monument,
# Nearest to th: accordingly, greco, steffens, spotless, decca, removing, disapproval, bards,
# Nearest to or: computed, unseated, dealerships, repeated, constitutionally, kali, spymaster, offshore,
# Nearest to six: floats, intermarried, attitudes, cretan, churchman, effigies, worsening, asynchronous,
# Nearest to for: multiple, littoral, materials, effect, strict, utah, aggression, asch,
# Nearest to which: lust, suggestions, molecular, ral, varied, exp, experiments, initiatives,
# Nearest to so: black, pumice, additional, estonian, rocket, radius, weeds, topology,
# Nearest to writers: plethora, decimated, montaigne, reznor, hyperbole, playhouse, tested, doubts,
# Nearest to applied: theorems, aldous, imagination, apoplexy, peckinpah, betts, dialectical, permissible,
# Nearest to lived: deduced, dared, toughest, acyclic, daily, prof, logical, droste,
# Nearest to award: conceived, vukovar, argues, havenco, forgery, philip, sensations, bellows,
# Nearest to instance: leguizamo, rsa, wilson, strings, dern, evaluate, twenties, missions,
# Nearest to event: slower, df, casio, eighteen, xiong, twin, dodos, waging,
# Nearest to rise: graduation, answer, assizes, austro, electrolytes, astros, convenes, lr,
# Nearest to recorded: wavelengths, formally, explosively, xviii, infinitive, consultative, templates, textile,
# Epoch 1/15 Iteration: 3100 Avg. Training loss: 4.8335 0.0389 sec/batch
# Epoch 1/15 Iteration: 3200 Avg. Training loss: 4.8051 0.0378 sec/batch
# Epoch 1/15 Iteration: 3300 Avg. Training loss: 4.7550 0.0377 sec/batch
# Epoch 1/15 Iteration: 3400 Avg. Training loss: 4.7766 0.0378 sec/batch
# Epoch 1/15 Iteration: 3500 Avg. Training loss: 4.7939 0.0381 sec/batch
# Epoch 1/15 Iteration: 3600 Avg. Training loss: 4.7323 0.0379 sec/batch
# Epoch 1/15 Iteration: 3700 Avg. Training loss: 4.7447 0.0377 sec/batch
# Epoch 1/15 Iteration: 3800 Avg. Training loss: 4.7835 0.0377 sec/batch
# Epoch 1/15 Iteration: 3900 Avg. Training loss: 4.7379 0.0378 sec/batch
# Epoch 1/15 Iteration: 4000 Avg. Training loss: 4.7032 0.0376 sec/batch
# Nearest to their: posteriori, most, challengers, ifr, transformers, fallacies, constituted, dimension,
# Nearest to people: talk, rowland, chats, eng, pooled, feeders, creditor, dames,
# Nearest to th: greco, spotless, steffens, tirpitz, bards, rebecca, tokugawa, evangelism,
# Nearest to or: computed, unseated, kali, constitutionally, dealerships, repeated, spymaster, offshore,
# Nearest to six: churchman, effigies, floats, intermarried, cretan, oglethorpe, worsening, essayists,
# Nearest to for: littoral, multiple, utah, sukarno, strict, aggression, materials, taborites,
# Nearest to which: lust, suggestions, ral, exp, molecular, expertise, truetype, varied,
# Nearest to so: black, pumice, weeds, rocket, estonian, additional, kitts, topology,
# Nearest to writers: plethora, hyperbole, drabble, randell, playhouse, decimated, reznor, hasn,
# Nearest to applied: theorems, aldous, imagination, apoplexy, dialectical, peckinpah, dislike, permissible,
# Nearest to lived: deduced, dared, toughest, acyclic, daily, droste, duchy, prof,
# Nearest to award: conceived, havenco, og, philip, vukovar, strau, forgery, bes,
# Nearest to instance: leguizamo, rsa, strings, dern, wilson, nistru, outreach, evaluate,
# Nearest to event: df, eighteen, casio, dodos, slower, interventionism, xiong, waging,
# Nearest to rise: graduation, austro, assizes, answer, lr, electrolytes, rica, convenes,
# Nearest to recorded: formally, wavelengths, explosively, xviii, consultative, textile, templates, infinitive,
# Epoch 1/15 Iteration: 4100 Avg. Training loss: 4.7351 0.0387 sec/batch
# Epoch 1/15 Iteration: 4200 Avg. Training loss: 4.6939 0.0377 sec/batch
# Epoch 1/15 Iteration: 4300 Avg. Training loss: 4.6551 0.0378 sec/batch
# Epoch 1/15 Iteration: 4400 Avg. Training loss: 4.6547 0.0378 sec/batch
# Epoch 1/15 Iteration: 4500 Avg. Training loss: 4.6732 0.0378 sec/batch
# Epoch 1/15 Iteration: 4600 Avg. Training loss: 4.6710 0.0377 sec/batch
# Epoch 2/15 Iteration: 4700 Avg. Training loss: 4.5997 0.0278 sec/batch
# Epoch 2/15 Iteration: 4800 Avg. Training loss: 4.5488 0.0378 sec/batch
# Epoch 2/15 Iteration: 4900 Avg. Training loss: 4.5104 0.0380 sec/batch
# Epoch 2/15 Iteration: 5000 Avg. Training loss: 4.4991 0.0379 sec/batch
# Nearest to their: posteriori, most, transformers, ifr, challengers, fallacies, bargain, constituted,
# Nearest to people: pooled, rowland, talk, creditor, chats, feeders, mana, dames,
# Nearest to th: greco, spotless, tokugawa, tirpitz, steffens, tendons, politicians, bards,
# Nearest to or: computed, unseated, dealerships, constitutionally, kali, spymaster, repeated, wertham,
# Nearest to six: churchman, effigies, intermarried, floats, cretan, oglethorpe, worsening, essayists,
# Nearest to for: multiple, littoral, sukarno, taborites, quran, infielder, effect, jeannette,
# Nearest to which: lust, suggestions, exp, truetype, ral, varied, ferry, experiments,
# Nearest to so: pumice, rocket, radius, black, additional, weeds, concave, oscillating,
# Nearest to writers: drabble, plethora, hyperbole, playhouse, randell, reznor, decimated, performances,
# Nearest to applied: theorems, apoplexy, aldous, imagination, permissible, midyear, dialectical, peckinpah,
# Nearest to lived: dared, deduced, toughest, droste, acyclic, daily, duchy, iberia,
# Nearest to award: conceived, og, havenco, thompson, forgery, carlo, philip, mayor,
# Nearest to instance: leguizamo, nistru, rsa, strings, dern, evaluate, outreach, romanized,
# Nearest to event: df, eighteen, casio, slower, interventionism, dodos, waging, xiong,
# Nearest to rise: lr, graduation, assizes, austro, electrolytes, convenes, rica, astros,
# Nearest to recorded: formally, xviii, explosively, wavelengths, ewen, alemannic, infinitive, textile,
# Epoch 2/15 Iteration: 5100 Avg. Training loss: 4.4650 0.0390 sec/batch
# Epoch 2/15 Iteration: 5200 Avg. Training loss: 4.5019 0.0377 sec/batch
# Epoch 2/15 Iteration: 5300 Avg. Training loss: 4.4491 0.0378 sec/batch
# Epoch 2/15 Iteration: 5400 Avg. Training loss: 4.5208 0.0376 sec/batch
# Epoch 2/15 Iteration: 5500 Avg. Training loss: 4.4849 0.0379 sec/batch
# Epoch 2/15 Iteration: 5600 Avg. Training loss: 4.4735 0.0377 sec/batch
# Epoch 2/15 Iteration: 5700 Avg. Training loss: 4.4577 0.0378 sec/batch
# Epoch 2/15 Iteration: 5800 Avg. Training loss: 4.4003 0.0378 sec/batch
# Epoch 2/15 Iteration: 5900 Avg. Training loss: 4.4569 0.0377 sec/batch
# Epoch 2/15 Iteration: 6000 Avg. Training loss: 4.4203 0.0376 sec/batch
# Nearest to their: posteriori, most, challengers, fallacies, constituted, bargain, transformers, ifr,
# Nearest to people: pooled, creditor, chats, rowland, mana, icrm, talk, jacobean,
# Nearest to th: greco, spotless, tirpitz, tokugawa, bantu, knightly, denomination, bards,
# Nearest to or: computed, unseated, kali, dealerships, constitutionally, spymaster, repeated, leukemia,
# Nearest to six: churchman, effigies, intermarried, oglethorpe, floats, worsening, zero, venona,
# Nearest to for: multiple, infielder, littoral, quran, effect, taborites, sukarno, jeannette,
# Nearest to which: lust, exp, suggestions, ral, truetype, molecular, ferry, varied,
# Nearest to so: pumice, radius, black, concave, additional, rocket, deviate, function,
# Nearest to writers: playhouse, hyperbole, plethora, drabble, randell, reznor, performances, wed,
# Nearest to applied: theorems, apoplexy, aldous, permissible, imagination, midyear, ionospheric, byte,
# Nearest to lived: deduced, dared, droste, acyclic, toughest, daily, duchy, iberia,
# Nearest to award: conceived, og, havenco, thompson, carlo, forgery, diderot, bes,
# Nearest to instance: leguizamo, rsa, strings, nistru, evaluate, dern, outreach, calcium,
# Nearest to event: df, eighteen, slower, casio, dodos, waging, interventionism, xiong,
# Nearest to rise: lr, electrolytes, graduation, assizes, rica, convenes, answer, austro,
# Nearest to recorded: explosively, formally, wavelengths, xviii, archaeologically, ewen, alemannic, muralitharan,
# Epoch 2/15 Iteration: 6100 Avg. Training loss: 4.4587 0.0389 sec/batch
# Epoch 2/15 Iteration: 6200 Avg. Training loss: 4.4209 0.0377 sec/batch
# Epoch 2/15 Iteration: 6300 Avg. Training loss: 4.4519 0.0378 sec/batch
# Epoch 2/15 Iteration: 6400 Avg. Training loss: 4.4085 0.0377 sec/batch
# Epoch 2/15 Iteration: 6500 Avg. Training loss: 4.3960 0.0377 sec/batch
# Epoch 2/15 Iteration: 6600 Avg. Training loss: 4.4338 0.0378 sec/batch
# Epoch 2/15 Iteration: 6700 Avg. Training loss: 4.3660 0.0379 sec/batch
# Epoch 2/15 Iteration: 6800 Avg. Training loss: 4.3783 0.0378 sec/batch
# Epoch 2/15 Iteration: 6900 Avg. Training loss: 4.3954 0.0378 sec/batch
# Epoch 2/15 Iteration: 7000 Avg. Training loss: 4.3756 0.0378 sec/batch
# Nearest to their: posteriori, most, challengers, fallacies, constituted, ws, transformers, diagnostics,
# Nearest to people: creditor, pooled, icrm, rowland, chats, mindaugas, capitulated, jacobean,
# Nearest to th: greco, spotless, tokugawa, tirpitz, denomination, knightly, delle, bards,
# Nearest to or: computed, kali, constitutionally, dealerships, unseated, repeated, spymaster, leukemia,
# Nearest to six: churchman, effigies, oglethorpe, floats, intermarried, zero, worsening, four,
# Nearest to for: multiple, infielder, xhtml, littoral, effect, compounding, lptb, taborites,
# Nearest to which: lust, suggestions, experiments, ral, truetype, molecular, ecm, exp,
# Nearest to so: black, concave, pumice, additional, radius, weeds, rocket, estonian,
# Nearest to writers: playhouse, hyperbole, drabble, plethora, randell, reznor, grasse, daw,
# Nearest to applied: theorems, apoplexy, aldous, imagination, permissible, ionospheric, experienced, dislike,
# Nearest to lived: dared, deduced, toughest, acyclic, droste, daily, duchy, iberia,
# Nearest to award: conceived, og, havenco, thompson, awards, carlo, diderot, won,
# Nearest to instance: leguizamo, rsa, nistru, strings, evaluate, dern, outreach, enabling,
# Nearest to event: df, slower, eighteen, casio, dodos, waging, interventionism, lewd,
# Nearest to rise: lr, assizes, graduation, electrolytes, answer, rica, austro, seaworthy,
# Nearest to recorded: explosively, archaeologically, wavelengths, xviii, formally, muralitharan, ewen, tavola,
# Epoch 2/15 Iteration: 7100 Avg. Training loss: 4.3783 0.0388 sec/batch
# Epoch 2/15 Iteration: 7200 Avg. Training loss: 4.4015 0.0378 sec/batch
# Epoch 2/15 Iteration: 7300 Avg. Training loss: 4.3157 0.0378 sec/batch
# Epoch 2/15 Iteration: 7400 Avg. Training loss: 4.3670 0.0378 sec/batch
# Epoch 2/15 Iteration: 7500 Avg. Training loss: 4.3886 0.0377 sec/batch
# Epoch 2/15 Iteration: 7600 Avg. Training loss: 4.3811 0.0378 sec/batch
# Epoch 2/15 Iteration: 7700 Avg. Training loss: 4.3574 0.0379 sec/batch
# Epoch 2/15 Iteration: 7800 Avg. Training loss: 4.3743 0.0379 sec/batch
# Epoch 2/15 Iteration: 7900 Avg. Training loss: 4.3056 0.0379 sec/batch
# Epoch 2/15 Iteration: 8000 Avg. Training loss: 4.3246 0.0377 sec/batch
# Nearest to their: posteriori, most, constituted, challengers, ifr, fallacies, ws, diagnostics,
# Nearest to people: creditor, sco, chats, pooled, rowland, capitulated, icrm, capsized,
# Nearest to th: greco, tokugawa, denomination, spotless, tirpitz, tendons, knightly, delle,
# Nearest to or: computed, constitutionally, kali, unseated, dealerships, spymaster, leukemia, repeated,
# Nearest to six: zero, effigies, churchman, worsening, oglethorpe, four, floats, jyutping,
# Nearest to for: multiple, xhtml, lptb, infielder, compounding, taborites, cocky, sukarno,
# Nearest to which: lust, truetype, suggestions, ral, varied, hanover, expertise, experiments,
# Nearest to so: pumice, black, estonian, concave, tenderness, radius, weeds, lebrun,
# Nearest to writers: hyperbole, playhouse, drabble, plethora, randell, reznor, grasse, daw,
# Nearest to applied: theorems, apoplexy, aldous, ionospheric, imagination, permissible, experienced, amplified,
# Nearest to lived: dared, deduced, acyclic, toughest, duchy, daily, droste, iberia,
# Nearest to award: conceived, awards, og, havenco, thompson, diderot, glenn, bes,
# Nearest to instance: leguizamo, nistru, rsa, strings, evaluate, dern, flyweight, facile,
# Nearest to event: df, eighteen, dodos, slower, casio, waging, interventionism, kidding,
# Nearest to rise: lr, assizes, seaworthy, isthmian, rica, austro, nomads, electrolytes,
# Nearest to recorded: explosively, archaeologically, formally, wavelengths, xviii, ewen, muralitharan, nudge,
# Epoch 2/15 Iteration: 8100 Avg. Training loss: 4.3517 0.0391 sec/batch
# Epoch 2/15 Iteration: 8200 Avg. Training loss: 4.2747 0.0379 sec/batch
# Epoch 2/15 Iteration: 8300 Avg. Training loss: 4.3649 0.0379 sec/batch
# Epoch 2/15 Iteration: 8400 Avg. Training loss: 4.3800 0.0377 sec/batch
# Epoch 2/15 Iteration: 8500 Avg. Training loss: 4.3756 0.0378 sec/batch
# Epoch 2/15 Iteration: 8600 Avg. Training loss: 4.2775 0.0377 sec/batch
# Epoch 2/15 Iteration: 8700 Avg. Training loss: 4.2942 0.0377 sec/batch
# Epoch 2/15 Iteration: 8800 Avg. Training loss: 4.3208 0.0378 sec/batch
# Epoch 2/15 Iteration: 8900 Avg. Training loss: 4.1968 0.0378 sec/batch
# Epoch 2/15 Iteration: 9000 Avg. Training loss: 4.3183 0.0380 sec/batch
# Nearest to their: posteriori, most, challengers, bargain, constituted, ibiza, agee, mjd,
# Nearest to people: creditor, icrm, chats, capitulated, sco, mindaugas, rowland, lawman,
# Nearest to th: greco, tokugawa, denomination, spotless, tirpitz, delle, knightly, regency,
# Nearest to or: computed, kali, constitutionally, unseated, dealerships, bottomed, spymaster, leukemia,
# Nearest to six: zero, churchman, four, one, oglethorpe, effigies, seven, eight,
# Nearest to for: multiple, cocky, taborites, lptb, effect, infielder, sukarno, xhtml,
# Nearest to which: varied, lust, ral, suggestions, suffices, experiments, truetype, exp,
# Nearest to so: black, concave, pumice, radius, immerse, rocket, weeds, tenderness,
# Nearest to writers: hyperbole, playhouse, plethora, drabble, randell, grasse, reznor, wed,
# Nearest to applied: apoplexy, theorems, ionospheric, aldous, experienced, eurozone, permissible, dialectical,
# Nearest to lived: dared, deduced, acyclic, iberia, toughest, daily, droste, duchy,
# Nearest to award: awards, conceived, og, havenco, diderot, seth, thompson, maradona,
# Nearest to instance: leguizamo, nistru, rsa, evaluate, strings, facile, flyweight, enabling,
# Nearest to event: eighteen, df, casio, slower, dodos, waging, interventionism, xiong,
# Nearest to rise: assizes, lr, nomads, seaworthy, electrolytes, austro, controlled, rica,
# Nearest to recorded: explosively, muralitharan, concacaf, nudge, tavola, wavelengths, outflows, clustered,
# Epoch 2/15 Iteration: 9100 Avg. Training loss: 4.2913 0.0390 sec/batch
# Epoch 2/15 Iteration: 9200 Avg. Training loss: 4.2972 0.0378 sec/batch
# Epoch 3/15 Iteration: 9300 Avg. Training loss: 4.3331 0.0171 sec/batch
# Epoch 3/15 Iteration: 9400 Avg. Training loss: 4.2151 0.0380 sec/batch
# Epoch 3/15 Iteration: 9500 Avg. Training loss: 4.2167 0.0380 sec/batch
# Epoch 3/15 Iteration: 9600 Avg. Training loss: 4.1964 0.0379 sec/batch
# Epoch 3/15 Iteration: 9700 Avg. Training loss: 4.1899 0.0378 sec/batch
# Epoch 3/15 Iteration: 9800 Avg. Training loss: 4.1847 0.0379 sec/batch
# Epoch 3/15 Iteration: 9900 Avg. Training loss: 4.1939 0.0378 sec/batch
# Epoch 3/15 Iteration: 10000 Avg. Training loss: 4.1369 0.0378 sec/batch
# Nearest to their: posteriori, challengers, most, ibiza, bargain, ws, khanty, mjd,
# Nearest to people: creditor, pooled, capitulated, chats, jacobean, mindaugas, rendition, icrm,
# Nearest to th: greco, denomination, tokugawa, spotless, delle, tirpitz, bounded, bantu,
# Nearest to or: kali, computed, constitutionally, unseated, dealerships, bottomed, nailed, leukemia,
# Nearest to six: zero, four, churchman, oglethorpe, effigies, one, two, seven,
# Nearest to for: multiple, cocky, effect, taborites, lptb, hariri, jeannette, infielder,
# Nearest to which: varied, hanover, lust, greetings, suffices, ral, truetype, expertise,
# Nearest to so: radius, black, tenderness, concave, pumice, immerse, additional, estonian,
# Nearest to writers: hyperbole, playhouse, plethora, drabble, randell, grasse, polycarp, reznor,
# Nearest to applied: apoplexy, theorems, ionospheric, aldous, permissible, midyear, dialectical, eurozone,
# Nearest to lived: dared, deduced, acyclic, iberia, daily, toughest, duchy, droste,
# Nearest to award: awards, conceived, og, havenco, diderot, won, seth, maradona,
# Nearest to instance: leguizamo, nistru, evaluate, rsa, strings, facile, dern, flyweight,
# Nearest to event: eighteen, df, slower, casio, waging, dodos, kidding, interventionism,
# Nearest to rise: lr, assizes, austro, seaworthy, kongo, equatorial, nomads, electrolytes,
# Nearest to recorded: concacaf, explosively, formally, muralitharan, clustered, tavola, outflows, nudge,
# Epoch 3/15 Iteration: 10100 Avg. Training loss: 4.2293 0.0391 sec/batch
# Epoch 3/15 Iteration: 10200 Avg. Training loss: 4.2418 0.0378 sec/batch
# Epoch 3/15 Iteration: 10300 Avg. Training loss: 4.1935 0.0378 sec/batch
# Epoch 3/15 Iteration: 10400 Avg. Training loss: 4.1062 0.0378 sec/batch
# Epoch 3/15 Iteration: 10500 Avg. Training loss: 4.1692 0.0378 sec/batch
# Epoch 3/15 Iteration: 10600 Avg. Training loss: 4.1930 0.0379 sec/batch
# Epoch 3/15 Iteration: 10700 Avg. Training loss: 4.1210 0.0375 sec/batch
# Epoch 3/15 Iteration: 10800 Avg. Training loss: 4.1666 0.0378 sec/batch
# Epoch 3/15 Iteration: 10900 Avg. Training loss: 4.1728 0.0379 sec/batch
# Epoch 3/15 Iteration: 11000 Avg. Training loss: 4.1423 0.0380 sec/batch
# Nearest to their: posteriori, challengers, most, ibiza, khanty, bargain, ws, prospering,
# Nearest to people: creditor, pooled, capsized, jacobean, mindaugas, chats, capitulated, rendition,
# Nearest to th: greco, tirpitz, denomination, spotless, bounded, tokugawa, delle, spongy,
# Nearest to or: kali, constitutionally, computed, unseated, dealerships, nailed, may, experiential,
# Nearest to six: zero, four, churchman, effigies, seven, oglethorpe, two, one,
# Nearest to for: multiple, taborites, effect, cocky, zeros, xhtml, hariri, lptb,
# Nearest to which: octahedron, suffices, ideographic, varied, lust, ral, hanover, biomechanical,
# Nearest to so: radius, black, concave, pumice, tenderness, additional, immerse, deviate,
# Nearest to writers: hyperbole, playhouse, plethora, drabble, grasse, randell, polycarp, reznor,
# Nearest to applied: apoplexy, theorems, ionospheric, aldous, permissible, eurozone, experienced, midyear,
# Nearest to lived: deduced, dared, acyclic, toughest, mannerist, iberia, daily, droste,
# Nearest to award: awards, conceived, og, seth, havenco, diderot, maradona, bes,
# Nearest to instance: leguizamo, nistru, evaluate, strings, rsa, facile, romanized, flyweight,
# Nearest to event: eighteen, df, slower, casio, dodos, waging, kidding, aotearoa,
# Nearest to rise: lr, assizes, seaworthy, austro, nomads, electrolytes, eigenstates, kongo,
# Nearest to recorded: concacaf, explosively, outflows, diatonic, tavola, muralitharan, clustered, archaeologically,
# Epoch 3/15 Iteration: 11100 Avg. Training loss: 4.1628 0.0390 sec/batch
# Epoch 3/15 Iteration: 11200 Avg. Training loss: 4.1958 0.0378 sec/batch
# Epoch 3/15 Iteration: 11300 Avg. Training loss: 4.1472 0.0378 sec/batch
# Epoch 3/15 Iteration: 11400 Avg. Training loss: 4.1353 0.0376 sec/batch
# Epoch 3/15 Iteration: 11500 Avg. Training loss: 4.1626 0.0377 sec/batch
# Epoch 3/15 Iteration: 11600 Avg. Training loss: 4.1653 0.0378 sec/batch
# Epoch 3/15 Iteration: 11700 Avg. Training loss: 4.1973 0.0379 sec/batch
# Epoch 3/15 Iteration: 11800 Avg. Training loss: 4.1484 0.0376 sec/batch
# Epoch 3/15 Iteration: 11900 Avg. Training loss: 4.1112 0.0379 sec/batch
# Epoch 3/15 Iteration: 12000 Avg. Training loss: 4.1705 0.0377 sec/batch
# Nearest to their: posteriori, ibiza, challengers, most, paraphyletic, agee, bargain, mjd,
# Nearest to people: creditor, rendition, capsized, mindaugas, msf, capitulated, sco, lawman,
# Nearest to th: greco, denomination, tokugawa, tirpitz, spotless, sidi, bounded, brushed,
# Nearest to or: kali, constitutionally, computed, unseated, dealerships, may, nailed, popolare,
# Nearest to six: zero, one, four, two, churchman, seven, oglethorpe, three,
# Nearest to for: multiple, taborites, cocky, zeros, effect, unending, components, xhtml,
# Nearest to which: varied, lust, octahedron, hanover, suffices, ideographic, chalcogenides, biomechanical,
# Nearest to so: black, radius, tenderness, estonian, additional, immerse, concave, trophies,
# Nearest to writers: hyperbole, plethora, drabble, grasse, playhouse, randell, amyotrophic, sinope,
# Nearest to applied: apoplexy, theorems, ionospheric, aldous, experienced, dialectical, eurozone, permissible,
# Nearest to lived: deduced, dared, acyclic, mannerist, toughest, droste, duchy, daily,
# Nearest to award: awards, conceived, havenco, seth, diderot, og, maradona, bes,
# Nearest to instance: leguizamo, nistru, evaluate, rsa, strings, homology, facile, flyweight,
# Nearest to event: slower, df, casio, eighteen, waging, dodos, aotearoa, kidding,
# Nearest to rise: assizes, seaworthy, lr, austro, kongo, nomads, eigenstates, youngstown,
# Nearest to recorded: concacaf, explosively, outflows, diatonic, clustered, band, muralitharan, nudge,
# Epoch 3/15 Iteration: 12100 Avg. Training loss: 4.1854 0.0389 sec/batch
# Epoch 3/15 Iteration: 12200 Avg. Training loss: 4.1568 0.0379 sec/batch
# Epoch 3/15 Iteration: 12300 Avg. Training loss: 4.1697 0.0378 sec/batch
# Epoch 3/15 Iteration: 12400 Avg. Training loss: 4.1716 0.0378 sec/batch
# Epoch 3/15 Iteration: 12500 Avg. Training loss: 4.1212 0.0378 sec/batch
# Epoch 3/15 Iteration: 12600 Avg. Training loss: 4.1150 0.0377 sec/batch
# Epoch 3/15 Iteration: 12700 Avg. Training loss: 4.1573 0.0379 sec/batch
# Epoch 3/15 Iteration: 12800 Avg. Training loss: 4.1409 0.0379 sec/batch
# Epoch 3/15 Iteration: 12900 Avg. Training loss: 4.1720 0.0380 sec/batch
# Epoch 3/15 Iteration: 13000 Avg. Training loss: 4.2191 0.0379 sec/batch
# Nearest to their: posteriori, most, ibiza, challengers, precautionary, bargain, constituted, agee,
# Nearest to people: creditor, rendition, capsized, capitulated, lawman, homicidal, msf, sco,
# Nearest to th: greco, tirpitz, denomination, tokugawa, spotless, sidi, knightly, gosse,
# Nearest to or: kali, constitutionally, computed, unseated, dealerships, probate, spymaster, placing,
# Nearest to six: one, zero, four, seven, churchman, two, three, eight,
# Nearest to for: multiple, cocky, taborites, after, lptb, nora, indictment, effect,
# Nearest to which: hanover, lust, octahedron, quirin, varied, ideographic, suffices, chalcogenides,
# Nearest to so: black, tenderness, estonian, immerse, welling, berenguer, radius, trophies,
# Nearest to writers: plethora, hyperbole, playhouse, drabble, grasse, randell, alumni, novelists,
# Nearest to applied: apoplexy, theorems, aldous, ionospheric, permissible, eurozone, jintao, dialectical,
# Nearest to lived: deduced, dared, acyclic, mannerist, iberia, toughest, sculptures, duchy,
# Nearest to award: awards, conceived, seth, havenco, diderot, og, bes, recipients,
# Nearest to instance: leguizamo, nistru, evaluate, rsa, strings, romanized, facile, flyweight,
# Nearest to event: eighteen, slower, casio, df, waging, dodos, kidding, xiong,
# Nearest to rise: austro, assizes, lr, seaworthy, kongo, youngstown, nomads, controlled,
# Nearest to recorded: concacaf, explosively, clustered, muralitharan, nudge, diatonic, outflows, formally,
# Epoch 3/15 Iteration: 13100 Avg. Training loss: 4.2079 0.0389 sec/batch
# Epoch 3/15 Iteration: 13200 Avg. Training loss: 4.1412 0.0378 sec/batch
# Epoch 3/15 Iteration: 13300 Avg. Training loss: 4.1350 0.0377 sec/batch
# Epoch 3/15 Iteration: 13400 Avg. Training loss: 4.1298 0.0376 sec/batch
# Epoch 3/15 Iteration: 13500 Avg. Training loss: 4.0264 0.0378 sec/batch
# Epoch 3/15 Iteration: 13600 Avg. Training loss: 4.1210 0.0380 sec/batch
# Epoch 3/15 Iteration: 13700 Avg. Training loss: 4.1476 0.0376 sec/batch
# Epoch 3/15 Iteration: 13800 Avg. Training loss: 4.1033 0.0379 sec/batch
# Epoch 4/15 Iteration: 13900 Avg. Training loss: 4.1500 0.0065 sec/batch
# Epoch 4/15 Iteration: 14000 Avg. Training loss: 4.0980 0.0378 sec/batch
# Nearest to their: posteriori, challengers, ibiza, prospering, precautionary, bargain, most, paraphyletic,
# Nearest to people: creditor, sco, capitulated, chats, lawman, hispanic, homicidal, ethnicity,
# Nearest to th: greco, tirpitz, sidi, tokugawa, denomination, spotless, jurchen, gosse,
# Nearest to or: kali, constitutionally, computed, placing, unseated, dealerships, probate, eurotunnel,
# Nearest to six: zero, one, four, two, seven, three, churchman, eight,
# Nearest to for: multiple, cocky, taborites, lptb, effect, the, asch, unending,
# Nearest to which: hanover, suffices, octahedron, lust, chalcogenides, varied, despite, quirin,
# Nearest to so: radius, black, tenderness, concave, additional, estonian, trophies, immerse,
# Nearest to writers: plethora, playhouse, hyperbole, drabble, novelists, randell, alumni, grasse,
# Nearest to applied: apoplexy, aldous, theorems, ionospheric, stades, jintao, permissible, urbina,
# Nearest to lived: dared, deduced, iberia, mannerist, acyclic, sirhan, toughest, selznick,
# Nearest to award: awards, havenco, seth, conceived, nominations, diderot, won, bes,
# Nearest to instance: leguizamo, nistru, evaluate, strings, facile, rsa, romanized, enabling,
# Nearest to event: slower, eighteen, casio, df, waging, kidding, dodos, aotearoa,
# Nearest to rise: austro, kongo, lr, seaworthy, controlled, nomads, assizes, electrolytes,
# Nearest to recorded: concacaf, explosively, diatonic, clustered, muralitharan, outflows, band, nudge,
# Epoch 4/15 Iteration: 14100 Avg. Training loss: 4.0687 0.0390 sec/batch
# Epoch 4/15 Iteration: 14200 Avg. Training loss: 4.0557 0.0379 sec/batch
# Epoch 4/15 Iteration: 14300 Avg. Training loss: 4.0664 0.0378 sec/batch
# Epoch 4/15 Iteration: 14400 Avg. Training loss: 4.0259 0.0378 sec/batch
# Epoch 4/15 Iteration: 14500 Avg. Training loss: 4.0235 0.0378 sec/batch
# Epoch 4/15 Iteration: 14600 Avg. Training loss: 4.0203 0.0379 sec/batch
# Epoch 4/15 Iteration: 14700 Avg. Training loss: 4.0773 0.0378 sec/batch
# Epoch 4/15 Iteration: 14800 Avg. Training loss: 4.0653 0.0377 sec/batch
# Epoch 4/15 Iteration: 14900 Avg. Training loss: 4.0785 0.0377 sec/batch
# Epoch 4/15 Iteration: 15000 Avg. Training loss: 4.0473 0.0377 sec/batch
# Nearest to their: posteriori, challengers, prospering, ibiza, mjd, most, precautionary, bargain,
# Nearest to people: creditor, ethnicity, hispanic, capitulated, sco, homicidal, chats, talk,
# Nearest to th: tirpitz, greco, centuries, sidi, edirne, jurchen, knightly, denomination,
# Nearest to or: kali, constitutionally, placing, computed, probate, unseated, oxymoron, gravy,
# Nearest to six: zero, four, one, three, two, seven, churchman, oglethorpe,
# Nearest to for: multiple, cocky, lptb, taborites, after, by, zeros, it,
# Nearest to which: suffices, octahedron, chalcogenides, hanover, varied, by, greetings, ideographic,
# Nearest to so: black, radius, tenderness, immerse, estonian, trophies, scheele, additional,
# Nearest to writers: plethora, novelists, hyperbole, playhouse, drabble, alumni, grasse, randell,
# Nearest to applied: apoplexy, ionospheric, theorems, aldous, jintao, stades, permissible, eurozone,
# Nearest to lived: deduced, dared, acyclic, toughest, iberia, boudin, mannerist, sirhan,
# Nearest to award: awards, havenco, seth, conceived, nominations, diderot, recipients, stereocenter,
# Nearest to instance: leguizamo, nistru, evaluate, strings, romanized, rsa, facile, homology,
# Nearest to event: eighteen, slower, df, casio, waging, kidding, dodos, aotearoa,
# Nearest to rise: lr, austro, assizes, seaworthy, kongo, controlled, isthmian, youngstown,
# Nearest to recorded: explosively, concacaf, diatonic, muralitharan, outflows, shrink, formally, clustered,
# Epoch 4/15 Iteration: 15100 Avg. Training loss: 3.9909 0.0391 sec/batch
# Epoch 4/15 Iteration: 15200 Avg. Training loss: 3.9979 0.0379 sec/batch
# Epoch 4/15 Iteration: 15300 Avg. Training loss: 4.0084 0.0376 sec/batch
# Epoch 4/15 Iteration: 15400 Avg. Training loss: 4.0430 0.0377 sec/batch
# Epoch 4/15 Iteration: 15500 Avg. Training loss: 4.0692 0.0377 sec/batch
# Epoch 4/15 Iteration: 15600 Avg. Training loss: 4.0424 0.0377 sec/batch
# Epoch 4/15 Iteration: 15700 Avg. Training loss: 4.0260 0.0375 sec/batch
# Epoch 4/15 Iteration: 15800 Avg. Training loss: 4.0863 0.0378 sec/batch
# Epoch 4/15 Iteration: 15900 Avg. Training loss: 4.0653 0.0379 sec/batch
# Epoch 4/15 Iteration: 16000 Avg. Training loss: 4.0227 0.0378 sec/batch
# Nearest to their: posteriori, prospering, challengers, precautionary, ibiza, paraphyletic, mjd, bargain,
# Nearest to people: creditor, hispanic, homicidal, msf, talk, chats, capitulated, lawman,
# Nearest to th: tirpitz, centuries, greco, sidi, denomination, edirne, absalon, jurchen,
# Nearest to or: kali, constitutionally, computed, placing, probate, may, dealerships, cardiac,
# Nearest to six: zero, four, one, three, two, seven, churchman, eight,
# Nearest to for: multiple, taborites, and, the, it, lptb, ratchet, cocky,
# Nearest to which: suffices, chalcogenides, octahedron, hanover, lust, by, molecular, varied,
# Nearest to so: radius, tenderness, black, estonian, additional, immerse, lossy, lignin,
# Nearest to writers: plethora, novelists, hyperbole, playhouse, drabble, grasse, alumni, randell,
# Nearest to applied: apoplexy, theorems, ionospheric, aldous, augustinian, eurozone, stades, permissible,
# Nearest to lived: deduced, dared, acyclic, toughest, boudin, sirhan, mannerist, catesby,
# Nearest to award: awards, havenco, seth, conceived, recipients, diderot, nominations, prizes,
# Nearest to instance: leguizamo, nistru, evaluate, strings, rsa, romanized, facile, homology,
# Nearest to event: eighteen, slower, casio, df, waging, kidding, dodos, hosts,
# Nearest to rise: lr, seaworthy, controlled, assizes, austro, kongo, electrolytes, eigenstates,
# Nearest to recorded: explosively, concacaf, diatonic, muralitharan, shrink, clustered, outflows, multitude,
# Epoch 4/15 Iteration: 16100 Avg. Training loss: 4.0325 0.0390 sec/batch
# Epoch 4/15 Iteration: 16200 Avg. Training loss: 4.0944 0.0378 sec/batch
# Epoch 4/15 Iteration: 16300 Avg. Training loss: 4.0401 0.0379 sec/batch
# Epoch 4/15 Iteration: 16400 Avg. Training loss: 4.0304 0.0376 sec/batch
# Epoch 4/15 Iteration: 16500 Avg. Training loss: 4.0495 0.0377 sec/batch
# Epoch 4/15 Iteration: 16600 Avg. Training loss: 4.0307 0.0378 sec/batch
# Epoch 4/15 Iteration: 16700 Avg. Training loss: 4.0599 0.0377 sec/batch
# Epoch 4/15 Iteration: 16800 Avg. Training loss: 4.0359 0.0380 sec/batch
# Epoch 4/15 Iteration: 16900 Avg. Training loss: 4.0891 0.0379 sec/batch
# Epoch 4/15 Iteration: 17000 Avg. Training loss: 4.0677 0.0379 sec/batch
# Nearest to their: posteriori, precautionary, paraphyletic, ibiza, challengers, prospering, mjd, constituted,
# Nearest to people: creditor, chats, msf, capitulated, capsized, failing, vibrio, homicidal,
# Nearest to th: centuries, tirpitz, greco, century, denomination, jurchen, brahmi, sidi,
# Nearest to or: kali, constitutionally, probate, placing, oxymoron, computed, sines, unseated,
# Nearest to six: one, four, zero, three, two, seven, churchman, eight,
# Nearest to for: multiple, cocky, taborites, lptb, the, unending, it, and,
# Nearest to which: suffices, hanover, chalcogenides, octahedron, ideographic, lust, quirin, by,
# Nearest to so: estonian, black, berenguer, radius, additional, deviate, nestorius, tenderness,
# Nearest to writers: plethora, novelists, alumni, playhouse, hyperbole, drabble, grasse, randell,
# Nearest to applied: apoplexy, ionospheric, theorems, aldous, stades, jintao, eurozone, dislike,
# Nearest to lived: deduced, dared, acyclic, toughest, sirhan, boudin, catesby, selznick,
# Nearest to award: awards, havenco, seth, oshii, conceived, eminem, recipients, diderot,
# Nearest to instance: leguizamo, nistru, evaluate, strings, romanized, facile, homology, enabling,
# Nearest to event: eighteen, casio, df, slower, waging, kidding, poised, aotearoa,
# Nearest to rise: austro, seaworthy, assizes, controlled, lr, youngstown, isthmian, kongo,
# Nearest to recorded: concacaf, diatonic, explosively, muralitharan, clustered, shrink, outflows, multitude,
# Epoch 4/15 Iteration: 17100 Avg. Training loss: 4.0254 0.0389 sec/batch
# Epoch 4/15 Iteration: 17200 Avg. Training loss: 3.9979 0.0377 sec/batch
# Epoch 4/15 Iteration: 17300 Avg. Training loss: 4.0055 0.0377 sec/batch
# Epoch 4/15 Iteration: 17400 Avg. Training loss: 4.0596 0.0380 sec/batch
# Epoch 4/15 Iteration: 17500 Avg. Training loss: 4.0505 0.0380 sec/batch
# Epoch 4/15 Iteration: 17600 Avg. Training loss: 4.1252 0.0378 sec/batch
# Epoch 4/15 Iteration: 17700 Avg. Training loss: 4.1214 0.0377 sec/batch
# Epoch 4/15 Iteration: 17800 Avg. Training loss: 4.0145 0.0378 sec/batch
# Epoch 4/15 Iteration: 17900 Avg. Training loss: 3.9988 0.0378 sec/batch
# Epoch 4/15 Iteration: 18000 Avg. Training loss: 4.0328 0.0376 sec/batch
# Nearest to their: posteriori, ibiza, precautionary, paraphyletic, prospering, challengers, consults, agee,
# Nearest to people: creditor, msf, chats, lawman, sarcastic, ethnicity, homicidal, capitulated,
# Nearest to th: centuries, greco, tirpitz, denomination, edirne, jurchen, century, absalon,
# Nearest to or: constitutionally, kali, probate, computed, oxymoron, placing, may, sines,
# Nearest to six: zero, four, one, three, two, seven, eight, churchman,
# Nearest to for: multiple, the, cocky, and, lptb, it, taborites, unending,
# Nearest to which: chalcogenides, suffices, hanover, octahedron, by, lust, exp, suggestions,
# Nearest to so: black, tenderness, radius, scheele, estonian, berenguer, immerse, suvs,
# Nearest to writers: plethora, novelists, alumni, playhouse, grasse, actors, drabble, hyperbole,
# Nearest to applied: apoplexy, ionospheric, eurozone, theorems, stades, aldous, permissible, jintao,
# Nearest to lived: deduced, dared, acyclic, sirhan, toughest, boudin, iberia, mannerist,
# Nearest to award: awards, havenco, prizes, seth, recipients, oshii, nominations, eminem,
# Nearest to instance: leguizamo, nistru, evaluate, strings, romanized, enabling, homology, facile,
# Nearest to event: eighteen, casio, slower, df, waging, kidding, poised, dodos,
# Nearest to rise: seaworthy, austro, controlled, assizes, youngstown, kongo, isthmian, lr,
# Nearest to recorded: concacaf, explosively, diatonic, muralitharan, shrink, clustered, menace, formally,
# Epoch 4/15 Iteration: 18100 Avg. Training loss: 3.9755 0.0390 sec/batch
# Epoch 4/15 Iteration: 18200 Avg. Training loss: 4.0424 0.0378 sec/batch
# Epoch 4/15 Iteration: 18300 Avg. Training loss: 4.0439 0.0378 sec/batch
# Epoch 4/15 Iteration: 18400 Avg. Training loss: 4.0309 0.0377 sec/batch
# Epoch 4/15 Iteration: 18500 Avg. Training loss: 4.0763 0.0378 sec/batch
# Epoch 5/15 Iteration: 18600 Avg. Training loss: 4.0109 0.0336 sec/batch
# Epoch 5/15 Iteration: 18700 Avg. Training loss: 3.9870 0.0379 sec/batch
# Epoch 5/15 Iteration: 18800 Avg. Training loss: 3.9732 0.0379 sec/batch
# Epoch 5/15 Iteration: 18900 Avg. Training loss: 4.0232 0.0379 sec/batch
# Epoch 5/15 Iteration: 19000 Avg. Training loss: 3.9613 0.0379 sec/batch
# Nearest to their: posteriori, paraphyletic, prospering, consults, precautionary, ibiza, agee, challengers,
# Nearest to people: msf, creditor, ethnicity, hispanic, failing, solent, homicidal, capitulated,
# Nearest to th: centuries, century, edirne, greco, brahmi, jurchen, tirpitz, denomination,
# Nearest to or: kali, constitutionally, placing, oxymoron, probate, heresy, computed, dealerships,
# Nearest to six: four, one, zero, three, two, seven, eight, churchman,
# Nearest to for: multiple, the, cocky, it, to, and, lptb, unending,
# Nearest to which: suffices, hanover, octahedron, soundtracks, chalcogenides, the, by, lust,
# Nearest to so: black, scheele, radius, says, estonian, tenderness, suvs, berenguer,
# Nearest to writers: plethora, novelists, alumni, actors, playhouse, grasse, drabble, hyperbole,
# Nearest to applied: apoplexy, ionospheric, stades, aldous, jintao, augustinian, eurozone, theorems,
# Nearest to lived: deduced, dared, acyclic, boudin, sirhan, sem, catesby, iberia,
# Nearest to award: awards, academy, nominations, havenco, prizes, oshii, recipients, seth,
# Nearest to instance: leguizamo, nistru, evaluate, romanized, strings, facile, enabling, vogler,
# Nearest to event: casio, eighteen, slower, df, waging, hosts, kidding, dodos,
# Nearest to rise: seaworthy, austro, kongo, controlled, assizes, isthmian, limes, youngstown,
# Nearest to recorded: concacaf, explosively, diatonic, muralitharan, shrink, clustered, multitude, formally,
# Epoch 5/15 Iteration: 19100 Avg. Training loss: 3.9606 0.0390 sec/batch
# Epoch 5/15 Iteration: 19200 Avg. Training loss: 3.9209 0.0377 sec/batch
# Epoch 5/15 Iteration: 19300 Avg. Training loss: 3.9813 0.0377 sec/batch
# Epoch 5/15 Iteration: 19400 Avg. Training loss: 4.0137 0.0378 sec/batch
# Epoch 5/15 Iteration: 19500 Avg. Training loss: 3.9908 0.0378 sec/batch
# Epoch 5/15 Iteration: 19600 Avg. Training loss: 4.0107 0.0378 sec/batch
# Epoch 5/15 Iteration: 19700 Avg. Training loss: 3.8900 0.0378 sec/batch
# Epoch 5/15 Iteration: 19800 Avg. Training loss: 3.9708 0.0378 sec/batch
# Epoch 5/15 Iteration: 19900 Avg. Training loss: 3.9227 0.0376 sec/batch
# Epoch 5/15 Iteration: 20000 Avg. Training loss: 3.9545 0.0376 sec/batch
# Nearest to their: posteriori, paraphyletic, prospering, precautionary, challengers, agee, khanty, mjd,
# Nearest to people: msf, creditor, ethnicity, hispanic, failing, homicidal, rendition, capitulated,
# Nearest to th: century, centuries, edirne, jurchen, tirpitz, absalon, denomination, brahmi,
# Nearest to or: kali, constitutionally, probate, placing, oxymoron, malayalam, snack, unseated,
# Nearest to six: four, one, zero, three, two, seven, eight, five,
# Nearest to for: the, multiple, and, to, it, cocky, lptb, by,
# Nearest to which: the, chalcogenides, by, soundtracks, suffices, octahedron, despite, magnetite,
# Nearest to so: scheele, black, lignin, tenderness, estonian, strontium, radius, immerse,
# Nearest to writers: plethora, novelists, alumni, actors, playhouse, hyperbole, grasse, drabble,
# Nearest to applied: apoplexy, ionospheric, stades, jintao, eurozone, permissible, aldous, js,
# Nearest to lived: deduced, dared, acyclic, toughest, boudin, sirhan, mannerist, sem,
# Nearest to award: awards, academy, nominations, prizes, havenco, oshii, seth, recipients,
# Nearest to instance: leguizamo, nistru, strings, evaluate, romanized, enabling, facile, penthouse,
# Nearest to event: casio, eighteen, slower, df, waging, dodos, hosts, kidding,
# Nearest to rise: controlled, seaworthy, kongo, austro, eigenstates, olin, equatorial, assizes,
# Nearest to recorded: concacaf, explosively, diatonic, muralitharan, shrink, multitude, clustered, botanicals,
# Epoch 5/15 Iteration: 20100 Avg. Training loss: 3.9794 0.0389 sec/batch
# Epoch 5/15 Iteration: 20200 Avg. Training loss: 4.0050 0.0377 sec/batch
# Epoch 5/15 Iteration: 20300 Avg. Training loss: 3.9434 0.0377 sec/batch
# Epoch 5/15 Iteration: 20400 Avg. Training loss: 3.9794 0.0377 sec/batch
# Epoch 5/15 Iteration: 20500 Avg. Training loss: 3.9960 0.0377 sec/batch
# Epoch 5/15 Iteration: 20600 Avg. Training loss: 3.9620 0.0378 sec/batch
# Epoch 5/15 Iteration: 20700 Avg. Training loss: 3.9488 0.0378 sec/batch
# Epoch 5/15 Iteration: 20800 Avg. Training loss: 3.9943 0.0378 sec/batch
# Epoch 5/15 Iteration: 20900 Avg. Training loss: 3.9664 0.0379 sec/batch
# Epoch 5/15 Iteration: 21000 Avg. Training loss: 3.9756 0.0378 sec/batch
# Nearest to their: posteriori, paraphyletic, prospering, agee, challengers, precautionary, ulansey, ibiza,
# Nearest to people: msf, creditor, failing, ethnicity, rendition, chats, hispanic, homicidal,
# Nearest to th: century, centuries, edirne, tirpitz, jurchen, absalon, denomination, brahmi,
# Nearest to or: constitutionally, kali, probate, placing, oxymoron, may, snack, dealerships,
# Nearest to six: one, four, zero, three, two, seven, eight, five,
# Nearest to for: the, multiple, to, and, it, which, lptb, cocky,
# Nearest to which: the, by, suffices, despite, for, hanover, soundtracks, chalcogenides,
# Nearest to so: black, scheele, tenderness, nestorius, berenguer, immerse, welling, lignin,
# Nearest to writers: novelists, plethora, alumni, actors, grasse, hyperbole, playhouse, randell,
# Nearest to applied: apoplexy, ionospheric, permissible, theorems, stades, aldous, eurozone, js,
# Nearest to lived: deduced, acyclic, dared, toughest, boudin, sirhan, sem, catesby,
# Nearest to award: awards, nominations, academy, havenco, prizes, recipients, eminem, oshii,
# Nearest to instance: leguizamo, nistru, evaluate, strings, romanized, homology, penthouse, enabling,
# Nearest to event: casio, eighteen, slower, df, hosts, waging, extinction, dodos,
# Nearest to rise: controlled, seaworthy, kongo, assizes, austro, belatedly, sympathizers, isthmian,
# Nearest to recorded: explosively, concacaf, diatonic, muralitharan, shrink, multitude, mojo, clustered,
# Epoch 5/15 Iteration: 21100 Avg. Training loss: 4.0039 0.0389 sec/batch
# Epoch 5/15 Iteration: 21200 Avg. Training loss: 3.9519 0.0378 sec/batch
# Epoch 5/15 Iteration: 21300 Avg. Training loss: 3.9875 0.0378 sec/batch
# Epoch 5/15 Iteration: 21400 Avg. Training loss: 3.9836 0.0378 sec/batch
# Epoch 5/15 Iteration: 21500 Avg. Training loss: 3.9922 0.0379 sec/batch
# Epoch 5/15 Iteration: 21600 Avg. Training loss: 3.9758 0.0378 sec/batch
# Epoch 5/15 Iteration: 21700 Avg. Training loss: 3.9514 0.0376 sec/batch
# Epoch 5/15 Iteration: 21800 Avg. Training loss: 3.9376 0.0379 sec/batch
# Epoch 5/15 Iteration: 21900 Avg. Training loss: 3.9539 0.0377 sec/batch
# Epoch 5/15 Iteration: 22000 Avg. Training loss: 4.0305 0.0380 sec/batch
# Nearest to their: posteriori, precautionary, paraphyletic, prospering, agee, mjd, ibiza, collectors,
# Nearest to people: msf, creditor, ethnicity, chats, failing, veterans, injustice, rendition,
# Nearest to th: century, centuries, jurchen, brahmi, edirne, tirpitz, sidi, absalon,
# Nearest to or: constitutionally, probate, kali, oxymoron, dealerships, from, treats, snack,
# Nearest to six: one, zero, four, three, two, seven, eight, five,
# Nearest to for: the, to, multiple, and, it, which, cocky, lptb,
# Nearest to which: the, by, hanover, despite, for, chalcogenides, suffices, soundtracks,
# Nearest to so: scheele, black, nestorius, tenderness, berenguer, confidentiality, lignin, estonian,
# Nearest to writers: novelists, plethora, alumni, actors, grasse, hyperbole, randell, sachsen,
# Nearest to applied: apoplexy, ionospheric, stades, aldous, permissible, eurozone, jintao, ucla,
# Nearest to lived: deduced, dared, acyclic, sirhan, sem, toughest, mannerist, boudin,
# Nearest to award: awards, academy, nominations, prizes, recipients, havenco, oshii, eminem,
# Nearest to instance: leguizamo, nistru, evaluate, romanized, strings, penthouse, facile, enabling,
# Nearest to event: casio, eighteen, slower, extinction, df, hosts, waging, parameters,
# Nearest to rise: controlled, austro, seaworthy, kongo, assizes, sympathizers, olin, regina,
# Nearest to recorded: concacaf, explosively, diatonic, muralitharan, shrink, multitude, clustered, atone,
# Epoch 5/15 Iteration: 22100 Avg. Training loss: 3.9283 0.0391 sec/batch
# ...
# Epoch 6/15 Iteration: 27600 Avg. Training loss: 3.9546 0.0377 sec/batch
# Epoch 6/15 Iteration: 27700 Avg. Training loss: 3.9611 0.0378 sec/batch
# Epoch 7/15 Iteration: 27800 Avg. Training loss: 3.9746 0.0126 sec/batch
# Epoch 7/15 Iteration: 27900 Avg. Training loss: 3.8872 0.0378 sec/batch
# Epoch 7/15 Iteration: 28000 Avg. Training loss: 3.9190 0.0379 sec/batch
# Nearest to their: prospering, paraphyletic, posteriori, precautionary, them, ulansey, agee, challengers,
# Nearest to people: veterans, humanitarians, failing, positive, msf, creditor, woese, chats,
# Nearest to th: century, centuries, brahmi, jurchen, edirne, extant, odo, dates,
# Nearest to or: kali, oxymoron, probate, constitutionally, sines, from, imbalances, are,
# Nearest to six: one, zero, four, seven, two, three, eight, five,
# Nearest to for: the, and, to, which, it, with, by, cocky,
# Nearest to which: the, by, for, hanover, a, are, soundtracks, despite,
# Nearest to so: i, black, suvs, lignin, stereogram, berenguer, scheele, doublet,
# Nearest to writers: novelists, plethora, alumni, actors, grasse, sachsen, dramatists, acrobatics,
# Nearest to applied: apoplexy, stades, ionospheric, ucla, aldous, analyzing, absorbed, permissible,
# Nearest to lived: acyclic, sirhan, deduced, sem, dared, selznick, solidus, kamchatsky,
# Nearest to award: awards, academy, nominations, awarded, hugo, oscar, prizes, best,
# Nearest to instance: nistru, evaluate, leguizamo, strings, facile, penthouse, mistakenly, romanized,
# Nearest to event: casio, extinction, slower, eighteen, hosts, parameters, rimini, rhenish,
# Nearest to rise: kongo, controlled, eigenstates, seaworthy, plutocracy, youngstown, electrolytes, austro,
# Nearest to recorded: explosively, diatonic, muralitharan, concacaf, chronology, recordings, shrink, multitude,
# Epoch 7/15 Iteration: 28100 Avg. Training loss: 3.8932 0.0392 sec/batch
# Epoch 7/15 Iteration: 28200 Avg. Training loss: 3.8846 0.0378 sec/batch
# Epoch 7/15 Iteration: 28300 Avg. Training loss: 3.8944 0.0378 sec/batch
# Epoch 7/15 Iteration: 28400 Avg. Training loss: 3.8770 0.0379 sec/batch
# Epoch 7/15 Iteration: 28500 Avg. Training loss: 3.8335 0.0378 sec/batch
# Epoch 7/15 Iteration: 28600 Avg. Training loss: 3.9110 0.0377 sec/batch
# Epoch 7/15 Iteration: 28700 Avg. Training loss: 3.8912 0.0378 sec/batch
# Epoch 7/15 Iteration: 28800 Avg. Training loss: 3.9703 0.0379 sec/batch
# Epoch 7/15 Iteration: 28900 Avg. Training loss: 3.8161 0.0379 sec/batch
# Epoch 7/15 Iteration: 29000 Avg. Training loss: 3.8714 0.0378 sec/batch
# Nearest to their: prospering, paraphyletic, them, posteriori, precautionary, mjd, ulansey, challengers,
# Nearest to people: creditor, failing, positive, msf, chats, veterans, humanitarians, hispanic,
# Nearest to th: century, centuries, jurchen, brahmi, edirne, numeral, absalon, odo,
# Nearest to or: kali, probate, from, constitutionally, oxymoron, of, are, by,
# Nearest to six: one, two, zero, four, three, seven, eight, five,
# Nearest to for: the, and, to, with, by, it, which, in,
# Nearest to which: the, by, for, a, are, of, chalcogenides, despite,
# Nearest to so: i, lignin, berenguer, nestorius, scheele, suvs, black, do,
# Nearest to writers: novelists, plethora, alumni, grasse, sachsen, actors, fiction, amyotrophic,
# Nearest to applied: apoplexy, ionospheric, stades, permissible, ucla, analyzing, thermodynamics, absorbed,
# Nearest to lived: acyclic, deduced, sirhan, sem, selznick, kamchatsky, solidus, dared,
# Nearest to award: awards, academy, nominations, hugo, awarded, prizes, oscar, winners,
# Nearest to instance: nistru, leguizamo, evaluate, penthouse, romanized, strings, mistakenly, facile,
# Nearest to event: casio, extinction, slower, eighteen, hosts, parameters, rimini, semifinals,
# Nearest to rise: controlled, seaworthy, eigenstates, youngstown, plutocracy, brook, kongo, regina,
# Nearest to recorded: muralitharan, explosively, diatonic, chronology, concacaf, shrink, recordings, multitude,
# Epoch 7/15 Iteration: 29100 Avg. Training loss: 3.8689 0.0389 sec/batch
# Epoch 7/15 Iteration: 29200 Avg. Training loss: 3.8152 0.0375 sec/batch
# Epoch 7/15 Iteration: 29300 Avg. Training loss: 3.8770 0.0377 sec/batch
# Epoch 7/15 Iteration: 29400 Avg. Training loss: 3.9026 0.0378 sec/batch
# Epoch 7/15 Iteration: 29500 Avg. Training loss: 3.8657 0.0378 sec/batch
# Epoch 7/15 Iteration: 29600 Avg. Training loss: 3.8787 0.0378 sec/batch
# Epoch 7/15 Iteration: 29700 Avg. Training loss: 3.9547 0.0378 sec/batch
# Epoch 7/15 Iteration: 29800 Avg. Training loss: 3.8653 0.0380 sec/batch
# Epoch 7/15 Iteration: 29900 Avg. Training loss: 3.8671 0.0378 sec/batch
# Epoch 7/15 Iteration: 30000 Avg. Training loss: 3.9069 0.0378 sec/batch
# Nearest to their: prospering, them, paraphyletic, agee, posteriori, precautionary, mjd, they,
# Nearest to people: humanitarians, veterans, failing, positive, hispanic, msf, injustice, chats,
# Nearest to th: century, centuries, brahmi, deuterium, numeral, odo, edirne, absalon,
# Nearest to or: probate, kali, are, from, constitutionally, snack, sines, used,
# Nearest to six: one, four, two, seven, zero, three, eight, five,
# Nearest to for: the, and, which, to, with, by, it, multiple,
# Nearest to which: the, by, for, a, are, is, of, same,
# Nearest to so: i, berenguer, nestorius, lignin, do, is, ciphertext, scheele,
# Nearest to writers: novelists, plethora, alumni, grasse, sachsen, actors, dramatists, fiction,
# Nearest to applied: apoplexy, ionospheric, stades, permissible, kinetic, analyzing, ucla, eurozone,
# Nearest to lived: acyclic, deduced, sirhan, sem, selznick, kamchatsky, boudin, dared,
# Nearest to award: awards, academy, nominations, prizes, hugo, awarded, winners, oscar,
# Nearest to instance: evaluate, nistru, leguizamo, strings, mistakenly, penthouse, facile, waist,
# Nearest to event: casio, extinction, parameters, slower, eighteen, hosts, events, rimini,
# Nearest to rise: controlled, seaworthy, youngstown, regina, eigenstates, brook, plutocracy, electrolytes,
# Nearest to recorded: muralitharan, explosively, diatonic, shrink, concacaf, chronology, multitude, used,
# Epoch 7/15 Iteration: 30100 Avg. Training loss: 3.8980 0.0391 sec/batch
# Epoch 7/15 Iteration: 30200 Avg. Training loss: 3.9249 0.0378 sec/batch
# Epoch 7/15 Iteration: 30300 Avg. Training loss: 3.8921 0.0376 sec/batch
# Epoch 7/15 Iteration: 30400 Avg. Training loss: 3.8880 0.0379 sec/batch
# Epoch 7/15 Iteration: 30500 Avg. Training loss: 3.9159 0.0379 sec/batch
# Epoch 7/15 Iteration: 30600 Avg. Training loss: 3.8963 0.0378 sec/batch
# Epoch 7/15 Iteration: 30700 Avg. Training loss: 3.9211 0.0382 sec/batch
# Epoch 7/15 Iteration: 30800 Avg. Training loss: 3.9237 0.0378 sec/batch
# Epoch 7/15 Iteration: 30900 Avg. Training loss: 3.9037 0.0379 sec/batch
# Epoch 7/15 Iteration: 31000 Avg. Training loss: 3.8788 0.0379 sec/batch
# Nearest to their: them, paraphyletic, prospering, mjd, precautionary, they, ibiza, posteriori,
# Nearest to people: humanitarians, veterans, positive, chats, failing, msf, suicides, ethnicity,
# Nearest to th: century, centuries, jurchen, numeral, brahmi, edirne, absalon, odo,
# Nearest to or: kali, from, probate, are, of, oxymoron, constitutionally, snack,
# Nearest to six: one, four, two, zero, seven, three, eight, five,
# Nearest to for: the, and, which, to, with, it, are, by,
# Nearest to which: the, for, by, a, is, of, are, as,
# Nearest to so: nestorius, berenguer, i, scheele, lignin, do, confidentiality, ciphertext,
# Nearest to writers: novelists, plethora, alumni, fiction, grasse, actors, amyotrophic, dramatists,
# Nearest to applied: stades, apoplexy, ionospheric, permissible, analyzing, ucla, eurozone, auditioned,
# Nearest to lived: acyclic, deduced, sirhan, sem, kamchatsky, selznick, solidus, dared,
# Nearest to award: awards, hugo, academy, nominations, prizes, awarded, best, winners,
# Nearest to instance: nistru, evaluate, strings, leguizamo, facile, waist, penthouse, romanized,
# Nearest to event: casio, extinction, slower, parameters, eighteen, hosts, events, rimini,
# Nearest to rise: controlled, seaworthy, regina, eigenstates, youngstown, expect, kongo, brook,
# Nearest to recorded: muralitharan, explosively, chronology, diatonic, concacaf, shrink, taxonomies, multitude,
# Epoch 7/15 Iteration: 31100 Avg. Training loss: 3.8842 0.0389 sec/batch
# Epoch 7/15 Iteration: 31200 Avg. Training loss: 3.8931 0.0380 sec/batch
# Epoch 7/15 Iteration: 31300 Avg. Training loss: 3.8854 0.0379 sec/batch
# Epoch 7/15 Iteration: 31400 Avg. Training loss: 3.9290 0.0379 sec/batch
# Epoch 7/15 Iteration: 31500 Avg. Training loss: 4.0149 0.0378 sec/batch
# Epoch 7/15 Iteration: 31600 Avg. Training loss: 3.9200 0.0377 sec/batch
# Epoch 7/15 Iteration: 31700 Avg. Training loss: 3.8982 0.0379 sec/batch
# Epoch 7/15 Iteration: 31800 Avg. Training loss: 3.8546 0.0376 sec/batch
# Epoch 7/15 Iteration: 31900 Avg. Training loss: 3.8916 0.0377 sec/batch
# Epoch 7/15 Iteration: 32000 Avg. Training loss: 3.8010 0.0379 sec/batch
# Nearest to their: them, paraphyletic, prospering, mjd, they, precautionary, consults, posteriori,
# Nearest to people: chats, positive, humanitarians, msf, failing, veterans, ethnicity, injustice,
# Nearest to th: century, centuries, jurchen, numeral, brahmi, edirne, trade, dates,
# Nearest to or: from, are, of, probate, kali, constitutionally, the, usually,
# Nearest to six: one, two, zero, three, four, seven, eight, five,
# Nearest to for: the, and, which, with, by, are, in, other,
# Nearest to which: the, for, by, a, and, are, as, of,
# Nearest to so: i, nestorius, do, berenguer, ciphertext, scheele, desegregation, lignin,
# Nearest to writers: novelists, plethora, alumni, fiction, actors, grasse, dramatists, sachsen,
# Nearest to applied: stades, ionospheric, apoplexy, permissible, analyzing, kinetic, ucla, conventional,
# Nearest to lived: acyclic, sirhan, sem, deduced, kamchatsky, dared, boudin, selznick,
# Nearest to award: awards, hugo, academy, nominations, best, prizes, awarded, winners,
# Nearest to instance: evaluate, nistru, strings, facile, mistakenly, waist, leguizamo, penthouse,
# Nearest to event: casio, extinction, eighteen, slower, parameters, events, hosts, rimini,
# Nearest to rise: controlled, seaworthy, eigenstates, regina, austro, youngstown, plutocracy, kongo,
# Nearest to recorded: muralitharan, explosively, diatonic, chronology, shrink, concacaf, recordings, taxonomies,
# Epoch 10/15 Iteration: 44600 Avg. Training loss: 3.8514 0.0379 sec/batch
# Epoch 10/15 Iteration: 44700 Avg. Training loss: 3.8100 0.0376 sec/batch
# Epoch 10/15 Iteration: 44800 Avg. Training loss: 3.8370 0.0379 sec/batch
# Epoch 10/15 Iteration: 44900 Avg. Training loss: 3.8021 0.0379 sec/batch
# Epoch 10/15 Iteration: 45000 Avg. Training loss: 3.8113 0.0377 sec/batch
# Nearest to their: them, they, are, and, most, as, such, prospering,
# Nearest to people: humanitarians, injustice, entertainers, speak, suicides, chats, for, positive,
# Nearest to th: century, centuries, mattered, trade, trebuchet, odo, nd, numeral,
# Nearest to or: from, are, the, of, usually, by, used, a,
# Nearest to six: one, two, four, three, zero, seven, five, eight,
# Nearest to for: the, and, to, in, with, as, of, is,
# Nearest to which: the, and, from, of, by, for, a, is,
# Nearest to so: nestorius, scheele, had, to, i, do, alhambra, was,
# Nearest to writers: novelists, fiction, plethora, dramatists, alumni, misinterpretation, actors, sachsen,
# Nearest to applied: stades, smoker, analyzing, motu, eurozone, auditioned, rotors, tort,
# Nearest to lived: sem, acyclic, sirhan, kamchatsky, dared, deduced, boudin, selznick,
# Nearest to award: awards, best, hugo, academy, nominations, nominated, awarded, winners,
# Nearest to instance: return, waist, the, strings, they, mistakenly, even, common,
# Nearest to event: extinction, events, casio, thal, eighteen, occur, slower, winter,
# Nearest to rise: expect, eigenstates, regina, recent, seaworthy, fall, plutocracy, bliss,
# Nearest to recorded: muralitharan, chronology, explosively, taxonomies, recordings, diatonic, shrink, concacaf,
# Epoch 10/15 Iteration: 45100 Avg. Training loss: 3.8349 0.0390 sec/batch
# Epoch 10/15 Iteration: 45200 Avg. Training loss: 3.7901 0.0381 sec/batch
# Epoch 10/15 Iteration: 45300 Avg. Training loss: 3.9027 0.0378 sec/batch
# Epoch 10/15 Iteration: 45400 Avg. Training loss: 3.9010 0.0379 sec/batch
# Epoch 10/15 Iteration: 45500 Avg. Training loss: 3.8621 0.0377 sec/batch
# Epoch 10/15 Iteration: 45600 Avg. Training loss: 3.8261 0.0379 sec/batch
# Epoch 10/15 Iteration: 45700 Avg. Training loss: 3.7701 0.0377 sec/batch
# Epoch 10/15 Iteration: 45800 Avg. Training loss: 3.8170 0.0376 sec/batch
# Epoch 10/15 Iteration: 45900 Avg. Training loss: 3.7141 0.0379 sec/batch
# Epoch 10/15 Iteration: 46000 Avg. Training loss: 3.8885 0.0379 sec/batch
# Nearest to their: them, they, are, and, prospering, as, well, such,
# Nearest to people: humanitarians, injustice, speak, entertainers, suicides, who, chats, for,
# Nearest to th: century, centuries, mattered, nd, jurchen, trade, odo, rd,
# Nearest to or: are, from, usually, of, the, generally, also, either,
# Nearest to six: one, two, four, seven, zero, three, eight, five,
# Nearest to for: the, and, to, with, in, by, which, as,
# Nearest to which: the, a, by, and, for, as, are, from,
# Nearest to so: do, i, to, nestorius, was, scheele, had, doesn,
# Nearest to writers: novelists, fiction, plethora, alumni, dramatists, autodidacts, actors, sachsen,
# Nearest to applied: stades, smoker, motu, eurozone, analyzing, goodwin, ucla, ionospheric,
# Nearest to lived: sem, kamchatsky, sirhan, acyclic, dared, boudin, timurid, solidus,
# Nearest to award: awards, best, hugo, academy, nominations, received, nominated, emmy,
# Nearest to instance: return, mistakenly, maude, common, waist, strings, they, even,
# Nearest to event: events, extinction, casio, thal, helena, eighteen, occur, slower,
# Nearest to rise: expect, eigenstates, recent, regina, plutocracy, seaworthy, bliss, fall,
# Nearest to recorded: muralitharan, explosively, recordings, chronology, shrink, recording, taxonomies, jeff,
# Epoch 10/15 Iteration: 46100 Avg. Training loss: 3.8272 0.0390 sec/batch
# Epoch 10/15 Iteration: 46200 Avg. Training loss: 3.8260 0.0380 sec/batch
# Epoch 11/15 Iteration: 46300 Avg. Training loss: 3.8932 0.0083 sec/batch
# Epoch 11/15 Iteration: 46400 Avg. Training loss: 3.8088 0.0378 sec/batch
# Epoch 11/15 Iteration: 46500 Avg. Training loss: 3.8052 0.0378 sec/batch
# Epoch 11/15 Iteration: 46600 Avg. Training loss: 3.7946 0.0379 sec/batch
# Epoch 11/15 Iteration: 46700 Avg. Training loss: 3.8117 0.0380 sec/batch
# Epoch 11/15 Iteration: 46800 Avg. Training loss: 3.7902 0.0377 sec/batch
# Epoch 11/15 Iteration: 46900 Avg. Training loss: 3.8070 0.0377 sec/batch
# Epoch 11/15 Iteration: 47000 Avg. Training loss: 3.7779 0.0378 sec/batch
# Nearest to their: them, they, are, and, well, as, prospering, most,
# Nearest to people: humanitarians, entertainers, suicides, for, chats, speak, injustice, importing,
# Nearest to th: century, centuries, trade, mattered, nd, trebuchet, rd, odo,
# Nearest to or: from, of, are, usually, the, by, either, generally,
# Nearest to six: one, two, three, four, zero, seven, eight, five,
# Nearest to for: the, to, and, with, as, in, by, from,
# Nearest to which: the, by, a, from, and, for, of, is,
# Nearest to so: was, scheele, had, i, to, nestorius, not, alhambra,
# Nearest to writers: novelists, plethora, fiction, dramatists, alumni, sachsen, autodidacts, actors,
# Nearest to applied: stades, smoker, goodwin, motu, analyzing, rotors, damian, eurozone,
# Nearest to lived: sem, acyclic, sirhan, kamchatsky, dared, boudin, deduced, timurid,
# Nearest to award: awards, best, hugo, nominations, academy, nominated, winners, received,
# Nearest to instance: waist, mistakenly, maude, common, involved, strings, return, nistru,
# Nearest to event: events, extinction, casio, thal, helena, winter, eighteen, hosts,
# Nearest to rise: expect, eigenstates, regina, recent, brook, controlled, plutocracy, commutators,
# Nearest to recorded: muralitharan, recordings, explosively, chronology, taxonomies, jeff, shrink, concacaf,
# Epoch 11/15 Iteration: 47100 Avg. Training loss: 3.8327 0.0390 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
